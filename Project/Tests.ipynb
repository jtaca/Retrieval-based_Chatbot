# %%
import xml.etree.ElementTree as ET
root = ET.parse('KB.xml').getroot()

# %%
for type_tag in root.findall('documento/faq_list/faq/perguntas/pergunta'):
    value = type_tag.get('pergunta')
    #print(type_tag)

# %%
from xml.dom import minidom
xmldoc = minidom.parse('KB.xml')

itemlist = xmldoc.getElementsByTagName('pergunta')
print(itemlist[0])
# Out:
# <DOM Element: pergunta at 0x11193af20>

# %%
import xml.etree.cElementTree as ET

tree = ET.parse("KB.xml")
root = tree.getroot() 
root_tag = root.tag
print(root_tag) 

for form in root.findall("documento/faq_list/faq/perguntas/pergunta"):
    #print(form)
# Out:
#   File "<ipython-input-4-a6e77f50467f>", line 9
#     #print(form)
#                 ^
# SyntaxError: unexpected EOF while parsing

# %%
from xml.dom import minidom

# parse an xml file by name
mydoc = minidom.parse('KB.xml')

perguntas = mydoc.getElementsByTagName('perguntas')
numbQuestions= len(perguntas)
#QuestionMatrix=
# all items data
print('\nAll item data:')
i=0
for elem in perguntas:
    #print('\n'+elem.firstChild.data+'\n'+str(i))
    i+=1
print(numbQuestions)
i=0
pergunta = mydoc.getElementsByTagName('pergunta')  
for elem in pergunta:
    #print('\n'+elem.firstChild.data+'\n'+str(i))
    i+=1
print(i)
# Out:
# All item data:
# 615
# 2641

# %%
from xml.dom import minidom

mydoc = minidom.parse('KB.xml')

perguntas = mydoc.getElementsByTagName('perguntas')
numbQuestions = len(perguntas)

pergunta = mydoc.getElementsByTagName('pergunta')
numbIterations = len(pergunta)

print('Number of questions: '+str(numbQuestions)+
      '\n Number of question iterations: '+str(numbIterations)+
      '\n Number of iterations per question: '+str(numbIterations/numbQuestions))
# Out:
# Number of questions: 615
#  Number of question iterations: 2641
#  Number of iterations per question: 4.294308943089431

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('KB.xml')
root = tree.getroot()

QuestionNumber = 0

NumberOfQuestions = 0

Answers = {}
Questions = {}


# all items data
print('\nAll item data:')
for documento in root:
    print('Documento:')
    print(documento.text)
    for faq_list in documento:
        #print(faq_list.text)
        #print('faq_list:')
        for faq in faq_list:
            #print('faq text:')
            #print(faq.text)
            for perguntas in faq:
                #print('perguntas')
                if len(perguntas.attrib)!= 0:
                    print('\n ID to return: '+perguntas.attrib['id'])
                    answer_id = perguntas.attrib['id']
                    answer = perguntas.text
                    print('\n Answer: '+ answer )
                    #print(perguntas.text)
                
                QuestionNumber = 0
                for pergunta in perguntas:
                    
                    print('\n '+str(QuestionNumber)+': '+pergunta.text)
                    QuestionNumber += 1
                    NumberOfQuestions += 1
# Out:
# All item data:
# Documento:
#
#
#
#  0: Pode ser emitido Cartão Eletrónico da Empresa ou de Pessoa Coletiva às entidades titulares de Cartão Definitivo de Identificação de Pessoa Coletiva ou entidade equiparada, emitido antes do dia 31/12/2008 ou inscritas anteriormente a essa data?
#
#  1: É possível emitir Cartão Eletrónico da Empresa ou de Pessoa Coletiva às entidades titulares de Cartão Definitivo de Identificação de Pessoa Coletiva ou entidade equiparada, emitido antes do dia 31/12/2008 ou inscritas anteriormente a essa data?
#
#  2: Posso mandar fazer o Cartão Eletrónico da Empresa ou de Pessoa Coletiva às entidades titulares de Cartão Definitivo de Identificação de Pessoa Coletiva ou entidade equiparada, emitido antes do dia 31/12/2008 ou inscritas antes dessa data?
#
#  3: Quero emitir o Cartão Eletrónico da Empresa ou de Pessoa Coletiva às entidades titulares de Cartão Definitivo de Identificação de Pessoa Coletiva ou entidade equiparada, emitido antes do dia 31/12/2008 ou inscritas antes dessa data. É possivel?
#
#  ID to return: 1
#
#  Answer: Pode, desde que seja previamente pedido o Cartão da Empresa ou Cartão de Pessoa Coletiva, em suporte físico, que já contém o código de acesso ao cartão eletrónico.
#
#  0: Como pedir o Cartão Provisório de Identificação de Pessoa Coletiva?
#
#  1: Como requerer o Cartão Provisório de Identificação de Pessoa Coletiva?
#
#  2: O Cartão Provisório de Identificação de Pessoa Coletiva é solicitado de que forma?
#
#  3: O Cartão Provisório de Identificação de Pessoa Coletiva é pedido como?
#
#  ID to return: 2
#
#  Answer:       O Cartão Provisório de Identificação de Pessoa Coletiva deixou de ser emitido, uma vez que as alterações legislativas ao regime jurídico do RNPC, ocorridas pelo Decreto-Lei n.º 247-B/2008, de 30 de Dezembro, não contemplam a sua emissão.
#       Atualmente existe apenas o Cartão da Empresa e o Cartão de Pessoa Coletiva que são emitidos para entidades definitivamente registadas ou inscritas.
#
#
#  0: Quando é emitido o Cartão da Empresa/Cartão de Pessoa Coletiva?
#
#  1: O Cartão da Empresa/Cartão de Pessoa Coletiva é emitido quando?
#
#  2: Em que condições é o Cartão da Empresa/Cartão de Pessoa Coletiva emitido?
#
#  3: Cartão da Empresa/Cartão de Pessoa Coletiva é emitido em que ocasião?
#
#  ID to return: 3
#
#  Answer: O cartão (em suporte físico) deve ser previamente pedido e apenas é emitido desde que cumpridos os seguintes pressupostos, de verificação automática:      Se a entidade estiver inscrita definitivamente na Conservatória do Registo Comercial ou no Ficheiro Central de Pessoas Colectivas e não estiver extinta;
#       Se a entidade tiver apresentado a declaração de início de actividade para efeitos fiscais na Autoridade Tributária, quando a deva apresentar;
#       Se a entidade estiver inscrita na Segurança Social, se for caso disso.
#
#
#  0: Qual o custo do Cartão da Empresa e do Cartão de Pessoa Coletiva?
#
#  1: Quanto custa o Cartão da Empresa e o Cartão de Pessoa Coletiva?
#
#  2: Qual o preço do Cartão da Empresa e do Cartão de Pessoa Coletiva?
#
#  3: O Cartão da Empresa e o Cartão de Pessoa Coletiva custam quanto?
#
#  ID to return: 4
#
#  Answer: Qualquer um dos cartões custa € 14,00 por unidade.
#
#  0: Onde posso pedir o Cartão da Empresa e o Cartão de Pessoa Colectiva?
#
#  1: O Cartão da Empresa e o Cartão de Pessoa Colectiva são pedidos onde?
#
#  2: Em que local posso pedir o Cartão da Empresa e o Cartão de Pessoa Colectiva?
#
#  3: Em que zona posso mandar fazer o Cartão da Empresa e o Cartão de Pessoa Colectiva?
#
#  ID to return: 5
#
#  Answer:       Na Internet, no site da Empresa Online e no site do Instituto dos Registos e do Notariado;
#       Presencialmente, no RNPC, nas Conservatórias do Registo Comercial, nos postos de atendimento dos Registos e nos Postos de Atendimento do Registo Comercial das Lojas da Empresa.
#
#
#  0: Para onde é enviado o Cartão da Empresa e o Cartão de Pessoa Coletiva?
#
#  1: O Cartão da Empresa e o Cartão de Pessoa Coletiva são enviados para onde?
#
#  2: Onde recebo o Cartão da Empresa e o Cartão de Pessoa Coletiva?
#
#  3: Onde é entregue o Cartão da Empresa e o Cartão de Pessoa Coletiva?
#
#  ID to return: 6
#
#  Answer: São enviados para:      A morada indicada pelo requerente, quando este tenha legitimidade para representar a entidade (por exemplo: notário, advogado, solicitador, gerente ou outro representante);
#       A morada da sede da entidade, nos restantes casos e nos de constituição da empresa online e sempre que o pedido de cartão seja feito pela Internet.
#
#
#  0: O que é o Cartão da Empresa e o Cartão de Pessoa Coletiva?
#
#  1: O que define o Cartão da Empresa e o Cartão de Pessoa Coletiva?
#
#  2: Qual a definição de Cartão da Empresa e de Cartão de Pessoa Coletiva?
#
#  3: A que diz respeito o Cartão da Empresa e o Cartão de Pessoa Coletiva?
#
#  ID to return: 7
#
#  Answer:       É o novo documento de identificação múltipla das pessoas coletivas e entidades equiparadas que contém o número de identificação de pessoa coletiva (NIPC) que, à exceção dos comerciantes/empresários individuais e estabelecimentos individuais de responsabilidade limitada, corresponde ao Número de Identificação Fiscal e o número de inscrição na Segurança Social (NISS), no caso de entidades a ela sujeitas.
#       Este cartão contém ainda o CAE principal e até três CAE secundárias, a natureza jurídica da entidade e data da sua constituição. No verso do cartão físico é também mencionado o código de acesso à certidão permanente atribuído com a submissão da IES.
#       Este cartão é sempre disponibilizado em suporte eletrónico e também pode ser disponibilizado em suporte físico, a pedido dos interessados. O cartão da empresa ou de pessoa coletiva em suporte físico é disponibilizado gratuitamente às entidades que se constituam no âmbito da Empresa na Hora (ENH), da Sucursal na Hora (SNH) e da Associação na Hora (ANH) e ainda às empresas online (EOL) cujo registo seja desde logo efetuado com caráter definitivo.
#       Este documento substitui os cartões anteriormente emitidos pelo RNPC e pelos Serviços de Finanças.
#
#
#  0: Qual a validade do Cartão da Empresa e do Cartão de Pessoa Coletiva?
#
#  1: Quando expira o Cartão da Empresa e do Cartão de Pessoa Coletiva?
#
#  2: O Cartão da Empresa e do Cartão de Pessoa Coletiva é válido até quando?
#
#  3: Qual a duração do período de validade do Cartão da Empresa e do Cartão de Pessoa Coletiva?
#
#  ID to return: 8
#
#  Answer: A validade do cartão físico depende da validade dos elementos nele constantes. Por exemplo, se uma sociedade alterar a sua denominação, o cartão deixa de estar válido. No entanto, o Cartão Eletrónico contém a informação da entidade permanentemente actualizada.
#
#  0: Como posso pedir o Cartão Eletrónico da Empresa ou de Pessoa Coletiva?
#
#  1: Como requerer o Cartão Eletrónico da Empresa ou de Pessoa Coletiva?
#
#  2: O Cartão Eletrónico da Empresa ou de Pessoa Coletiva é solicitado de que forma?
#
#  3: O Cartão Eletrónico da Empresa ou de Pessoa Coletiva é pedido como?
#
#  ID to return: 9
#
#  Answer:       O código de acesso ao Cartão Eletrónico é atribuído automática e gratuitamente a todas as entidades no momento da sua constituição, exceto se se tratar de empresários e comerciantes em nome individual e de Estabelecimentos Individuais de Responsabilidade Limitada (EIRL). O Cartão Eletrónico da Empresa/Pessoa Coletiva não necessita de ser pedido.
#       Os empresários e comerciantes em nome individual, os Estabelecimentos Individuais de Responsabilidade Limitada (EIRL) e as entidades já constituídas, em data anterior à da entrada em vigor do Decreto-Lei n.º 247-B/2008, de 30 de Dezembro, que pretendam obter o código de acesso ao Cartão Eletrónico, devem requerer um Cartão da Empresa ou de Pessoa Coletiva através da Internet, no site Empresa Online ou no site do Instituto dos Registos e do Notariado, ou presencialmente, junto de qualquer Conservatória do Registo Comercial ou Loja da Empresa.
#
#
#  0: O Cartão de Identificação de Pessoa Coletiva ou entidade equiparada, emitido pelo RNPC e de que sou titular, continua a ser válido?
#
#  1: O Cartão de Identificação de Pessoa Coletiva ou entidade equiparada, emitido pelo RNPC e de que sou titular, mantêm a sua validade?
#
#  2: A validade do Cartão de Identificação de Pessoa Coletiva ou entidade equiparada, emitido pelo RNPC e de que sou titular, mantêm-se?
#
#  3: O Cartão de Identificação de Pessoa Coletiva ou entidade equiparada, emitido pelo RNPC e de que sou titular, permanece válido?
#
#  ID to return: 10
#
#  Answer:       Sim. Os cartões de identificação de pessoa coletiva e entidade equiparada emitidos pelo RNPC mantêm a sua validade.
#
#
#  0: O Cartão Eletrónico da Empresa ou de Pessoa Coletiva pode ser cancelado?
#
#  1: É possível cancelar o Cartão Eletrónico da Empresa ou de Pessoa Coletiva?
#
#  2: O Cartão Eletrónico da Empresa ou de Pessoa Coletiva pode ser anulado?
#
#  3: Em que casos pode ser cancelado o Cartão Eletrónico da Empresa ou de Pessoa Coletiva?
#
#  ID to return: 11
#
#  Answer:       Pode. Nos casos de extinção da entidade, transferência da sede para o estrangeiro e cessação de atividade do comerciante/empresário individual.
#
#
#  0: O Cartão da Empresa e o Cartão de Pessoa Coletiva podem ser cancelados?
#
#  1: É possível cancelar o Cartão da Empresa e o Cartão de Pessoa Coletiva?
#
#  2: O Cartão da Empresa e o Cartão de Pessoa Coletiva podem ser anulado?
#
#  3: Em que casos podem ser cancelados o Cartão da Empresa e o Cartão de Pessoa Coletiva?
#
#  ID to return: 12
#
#  Answer: Podem, nos seguintes casos:      Oficiosamente nos casos de extinção da entidade, transferência da sede para o estrangeiro e cessação de atividade do comerciante/empresário individual;
#       A pedido de quem tenha legitimidade para representar a entidade, nos casos de perda, destruição, furto ou roubo.
#
#
#  0: O que é o Cartão Eletrónico da Empresa e de Pessoa Coletiva?
#
#  1: O que define o Cartão Eletrónico da Empresa e de Pessoa Coletiva?
#
#  2: Qual a definição de Cartão Eletrónico da Empresa e de Pessoa Coletiva?
#
#  3: A que diz respeito o Cartão Eletrónico da Empresa e de Pessoa Coletiva?
#
#  ID to return: 13
#
#  Answer:       É um cartão disponibilizado de forma automática, na sequência da inscrição definitiva da entidade no FCPC, mediante a atribuição de um código de acesso.
#       A consulta ao cartão eletrónico pode ser efetuada no site da Empresa Online ou no site do Instituto dos Registos e do Notariado.
#       O Cartão Eletrónico contém a informação permanentemente actualizada, tem o mesmo valor do cartão emitido em suporte físico e é gratuito.
#
#
#  0: Qual a diferença entre o Cartão da Empresa e o Cartão de Pessoa Coletiva?
#
#  1: O que distingue o Cartão da Empresa do Cartão de Pessoa Coletiva?
#
#  2: Em que difere o Cartão da Empresa do Cartão de Pessoa Coletiva?
#
#  3: O Cartão da Empresa e o Cartão de Pessoa Coletiva são distinguidos como?
#
#  ID to return: 14
#
#  Answer: O Cartão da Empresa serve para a identificação das seguintes entidades:      Sociedades, cooperativas, agrupamentos complementares de empresas (ACE), agrupamentos europeus de interesse económico (AEIE), entidades públicas empresariais, estabelecimentos individuais de responsabilidade limitada (EIRL), sucursais de entidades estrangeiras, trust e demais entidades sujeitas a registo comercial;
#       Empresários individuais inscritos no FCPC.
# O Cartão de Pessoa Coletiva identifica as seguintes entidades:
#       Entidades inscritas no FCPC, mas não sujeitas a registo comercial (associações, fundações, pessoas coletivas religiosas, organismos da administração pública, condomínios, etc.);
#       Associações e fundações registadas nas conservatórias do registo comercial, devido ao seu reconhecimento como pessoas coletivas de utilidade pública.
#
# Documento:
#
#
#
#  0: Que tipo de sociedades podem ser constituídas através do serviço de criação de Empresa Online?
#
#  1: Quais são os tipos de sociedades podem ser constituídas através do serviço de criação de Empresa Online?
#
#  2: Que tipo de sociedades posso constituir através do serviço de criação de Empresa Online?
#
#  3: Que tipo de sociedades se conseguem constituir através do serviço de criação de Empresa Online?
#
#  ID to return: 15
#
#  Answer:         Sociedades comerciais e civis sob a forma comercial, do tipo por quotas, unipessoal por quotas e anónimas.
#         É possível optar-se por um pacto pré-aprovado ou por um pacto elaborado pelos próprios interessados.
#         Desde 27 de Setembro de 2007, encontra-se disponível a possibilidade de obtenção de uma Marca
#         Registada, no momento da constituição de uma Empresa Online que, no caso de constituição de sociedade, é equivalente à firma escolhida. Consultar Marcas e Patentes no elenco das Perguntas Frequentes.
#         Este serviço também permite a constituição de sociedades na sequência de uma fusão ou cisão.
#         Nesse caso, a conservatória à qual for.
#
#
#  0: Há sociedades que não podem ser constituídas através do serviço de criação de Empresa Online?
#
#  1: Há alguma sociedade que não possa ser constituída através do serviço de criação de Empresa Online?
#
#  2: Existem sociedades que não podem ser constituídas através do serviço de criação de Empresa Online?
#
#  3: Existe alguma sociedade que não possa ser constituída através do serviço de criação de Empresa Online?
#
#  ID to return: 16
#
#  Answer:         Sim, é o caso das sociedades anónimas europeias e das sociedades cujo capital seja realizado com recurso a entradas em espécie em que, para a transmissão dos bens com que os sócios entram para a sociedade, seja exigida forma mais solene do que a forma escrita.
#
#
#  0: A partir de onde poder ser acedido o serviço de criação de Empresa Online?
#
#  1: A partir de onde posso aceder ao serviço de criação de Empresa Online?
#
#  2: A partir de que sítio pode ser acedido o serviço de criação de Empresa Online?
#
#  3: A partir de onde se pode aceder ao serviço de criação de Empresa Online?
#
#  ID to return: 17
#
#  Answer:        A partir de um computador em sua casa, escritório ou num local com acesso à Internet, acedendo através do Portal da Empresa.
#
#
#  0: Quem pode constituir uma empresa através do serviço de criação de Empresa Online?
#
#  1: Quem é autorizado a constituir uma empresa através do serviço de criação de Empresa Online?
#
#  2: Quem é capaz de constituir uma empresa através do serviço de criação de Empresa Online?
#
#  3: Quem pode constituir uma empresa utilizando o serviço de criação de Empresa Online?
#
#  ID to return: 18
#
#  Answer:         Podem utilizar o serviço os Advogados, Solicitadores e Notários que possuam um certificado digital.
#         O serviço também está acessível a qualquer cidadão, desde que seja portador do Cartão de Cidadão
#         (neste caso, esclarece-se que todos os sócios deverão ser titulares do Cartão de Cidadão, de forma
#         a poderem assinar digitalmente o pacto) e não seja necessário juntar documentos para além do
#         pacto social.
#         Salienta-se, no entanto, que os Advogados, Solicitadores e Notários não podem agir como
#         representantes dos sócios na subscrição do pacto.
#         Cidadãos estónios e espanhóis podem criar uma empresa online recorrendo ao certificado do seu
#         documento nacional de identificação.
#
#
#  0: Como se escolhe a firma?
#
#  1: Como é que se escolhe a firma?
#
#  2: Como escolho a firma?
#
#  3: Como é escolhida a firma?
#
#  ID to return: 19
#
#  Answer:        O nome da Sociedade pode ser: escolhido da bolsa de nomes de fantasia criados e reservados a
# favor do Estado (com ou sem Marca associada); ter sido previamente aprovado pelo RNPC em
# certificado de admissibilidade que se encontre ainda dentro do prazo de validade; ser constituído
# por firma-nome aprovada automaticamente e, ainda, escolhido no próprio fluxo da constituição da
# Empresa Online, podendo para o efeito ser indicadas até 9 preferências e tendo os serviços o prazo
# máximo de um dia útil para a sua aprovação, a título gratuito. Neste caso o Advogado, Solicitador
# ou Notário detentor do certificado digital e que está a agir em representação do requerente, deve
# identificar-se na qualidade de subscritor e não de requerente, já que este é necessariamente um
# dos futuros sócios.
# No caso das firmas da Bolsa, se o apresentante, nos 30 minutos depois de seleccionar o “nome
# fantasia” , não passar da fase de introdução dos dados relativos à sociedade, será avisado para dar
# continuidade ao processo. Caso contrário, o nome deixa de estar reservado.
#
#
#  0: Para a constituição de uma empresa através do serviço de criação de Empresa Online é necessária
# a presença de todos os sócios?
#
#  1: É necessária a presença de todos os sócios para a constituição de uma empresa através do serviço de criação de Empresa Online?
#
#  2: Para a constituição de uma empresa através do serviço de criação de Empresa Online é precisa
# a presença de todos os sócios?
#
#  3: Para a constituição de uma empresa através do serviço de criação de Empresa Online todos os sócios têm de estar presentes?
#
#  ID to return: 20
#
#  Answer:        Nos casos em que os sócios se fazem representar por intermédio de uma procuração, basta a assinatura do procurador. Nos casos em que não há intervenção de procurador, será necessária a assinatura manuscrita de todos os sócios e respectivo reconhecimento presencial das mesmas pelo Advogado, Solicitador ou Notário.
#
#
#  0: Posso reservar previamente, de entre as firmas constantes da lista de nomes fantasia, o nome que
# pretendo para a minha empresa?
#
#  1: Posso reservar antecipadamente, de entre as firmas constantes da lista de nomes fantasia, o nome que
# pretendo para a minha empresa?
#
#  2: É possível reservar previamente, de entre as firmas constantes da lista de nomes fantasia, o nome que
# pretendo para a minha empresa?
#
#  3: É possível reservar antecipadamente, de entre as firmas constantes da lista de nomes fantasia, o nome que
# pretendo para a minha empresa?
#
#  ID to return: 21
#
#  Answer:        Não. A escolha da firma de entre as que constam da Bolsa apenas pode ser efectuada no momento da constituição da empresa.
#
#
#  0: Qual o custo de constituição de uma Empresa Online ou de uma Empresa Online com Marca
# associada?
#
#  1: Quanto custa de constituição de uma Empresa Online ou uma Empresa Online com Marca
# associada?
#
#  2: Qual o custo de constituir uma Empresa Online ou uma Empresa Online com Marca
# associada?
#
#  3: Qual é o custo para constituir uma Empresa Online ou uma Empresa Online com Marca
# associada?
#
#  ID to return: 22
#
#  Answer:         Os custos inerentes à constituição da sociedade são os seguintes:
#         € 220,00 (pacto ou ato constitutivo de modelo aprovado);
#         € 360,00 (pacto social livre - elaborado pelos interessados).
#         Acresce a estes valores, na constituição de sociedade com Marca associada com uma classe de
#         produtos ou serviços, € 100,00. A este valor acresce € 44,00 por cada classe adicional. (Consultar
#         área “Marcas e Patentes” no elenco das Perguntas Frequentes).
#         Os custos da constituição da Empresa Online incluem os da verificação da admissibilidade e
#         aprovação da firma no fluxo da EOL.
#
#
#  0: Quais são os prazos de pagamento associados ao serviço de criação de Empresa Online?
#
#  1: Quais são os prazos de pagamento relativos ao serviço de criação de Empresa Online?
#
#  2: Qual é o prazo de pagamento associado ao serviço de criação de Empresa Online?
#
#  3: Qual é o prazo para pagar a criação de uma Empresa Online?
#
#  ID to return: 23
#
#  Answer:        O prazo para execução do pagamento por Multibanco, e-Banking e Visa/MasterCard, através da
# referência fornecida, é no máximo de 48 horas úteis.
#
#
#  0: Caso existam inconformidades no processo, o que sucede?
#
#  1: Havendo inconformidades no processo, o que acontece?
#
#  2: Na eventualidade da existência de inconformidades no processo, qual é o procedimento?
#
#  3: O que sucede na ocorrência de inconformidades no processo?
#
#  ID to return: 24
#
#  Answer:  No caso de serem detectadas inconformidades no processo de constituição da empresa, o utilizador tem o prazo de cinco dias para proceder às respectivas correções.As inconformidades detectadas serão listadas na notificação enviada ao utilizador (via e-mail ou via telefone), que por sua vez terá de aceder à aplicação e proceder às respectivas correcções. Nas notificações serão mencionados quais os campos a corrigir.
# O custo do suprimento de deficiências é de € 30,00.
#
#
#  0: Quando deverei efectuar o depósito do capital social da Empresa Online?
#
#  1: Em que altura deve o depósito do capital social da Empresa Online ser feito?
#
#  2: O depósito do capital social da Empresa Online deve ser feito quando?
#
#  3: Quando devem os sócios fazer o depósito do capital social da Empresa Online?
#
#  ID to return: 25
#
#  Answer:        Caso o depósito do capital social ainda não tenha sido efectuado no momento da constituição da empresa, os sócios devem declarar, sob sua responsabilidade, que o mesmo será depositado, em dinheiro, no prazo de cinco dias a contar da disponibilização da Certidão Permanente ou, relativamente às sociedades por quotas ou unipessoais por quotas, proceder à sua entrega nos cofres da sociedade até ao final do primeiro exercício económico.
#
#
#  0:  Quando é possível o levantamento do capital social da Empresa Online?
#
#  1:  Em que altura posso fazer o levantamento do capital social da Empresa Social?
#
#  2:  Quando fica o capital social da Empresa Online disponível para levantamento?
#
#  3:  A partir de que momento se torna possível o levantamento do capital social da Empresa Online?
#
#  ID to return: 26
#
#  Answer: 	   É possível o levantamento do capital social da Empresa Online em qualquer momento após a sua constituição.
#
#
#  0:  A escolha de uma firma pré-aprovada pode limitar de alguma forma o objecto social que pretendo para a minha empresa?
#
#  1:  Pode o objecto social que quero para a minha empresa ficar de alguma forma limitado pela escolha duma firma pré-aprovada?
#
#  2:  É posssível que a escolha duma firma pré-aprovada limite o objecto social pretendido para a minha empresa?
#
#  3:  Pode a escolha de uma firma pré-aprovada de alguma forma limitar o objecto social que quero para a minha empresa?
#
#  ID to return: 27
#
#  Answer:  Não. As firmas pré-aprovadas são compostas por expressões de fantasia que não identificam qual a actividade, cabendo aos interessados decidir livremente se pretendem completar a firma com a descrição do objecto da sua sociedade.
#
#  0:  Disponho de um Certificado de Admissibilidade de firma válido. Posso utilizá-lo para constituir a minha empresa através do serviço de criação de Empresa Online?
#
#  1:  Tenho um Certificado de Admissibilidade de firma válido. Pode este ser utilizado para constituir a minha empresa através do serviço de criação de Empresa Online?
#
#  2:  Possuo um Certificado de Admissibilidade de firma válido. É possível utilizá-lo a fim de constituir a minha empresa através do serviço de criação de Empresa Online?
#
#  3:  Sendo eu possuidor dum Certificado de Admissibilidade de firma válido, posso, recorrendo ao serviço de criação de Empresa Online, utilizá-lo para constituir a minha empresa?
#
#  ID to return: 28
#
#  Answer:   Sim. Poderá com o Certificado de Admissibilidade efectuar a constituição da sua empresa através do serviço criação de Empresa Online, bastando para tal introduzir o Número de Identificação de Pessoa Colectiva associado. Desta forma o nome da firma é automaticamente identificado.
#
#  0:  Como poderei obter o certificado de Admissibilidade?
#
#  1:
#
#  2:
#
#  3:
#
#  ID to return: 29
#
#  Answer:  O pedido de Certificado de Admissibilidade pode ser pedido na Internet neste site ou no IRN, presencialmente no RNPC, por forma verbal, pelo próprio ou por pessoa com legitimidade para o efeito ou por escrito em formulário próprio (Modelo 1) ou ainda pelo correio, em formulário próprio (Modelo 1) enviado para o Apartado 4064-1501-803 Lisboa.
# 	   Os formulários do RNPC estão disponíveis gratuitamente no site do IRN.
#
#
#  0:  Como aceder ao fórum de validação do Pacto Social?
#
#  1:
#
#  2:
#
#  3:
#
#  ID to return: 30
#
#  Answer:  Nas situações em que o Apresentante tiver disponibilizado o Pacto Social no fórum, os sócios da empresa poderão:	   Visualizar o Pacto Social - No fórum, os sócios podem verificar o Pacto Social e têm a possibilidade de completar (no caso de pacto social eleborado pelos interessados), de indicar erros ou inconformidades que detectem.
# 	   Notificar o Apresentante - Caso identifiquem algum erro ou inconformidade, os sócios deverão notificar o apresentante relativamente às correcções a efectuar, através das funcionalidades disponíveis no fórum.
# 	   Completar Pacto (se pacto elaborado pelos interessados), corrigir erros ou inconformidades O apresentante recebe a notificação por parte dos sócios, efectuando posteriormente as revisões no Portal da Empresa acedendo através do Dossier Electrónico da Empresa.
# 	   ATENÇÃO:
# 	   O acesso ao fórum é efectuado pelo URL indicado no email recebido pelos sócios.
#
#
#
#  0:  A inscrição da sociedade nas finanças, na segurança social e outros serviços públicos são efectuados no momento da constituição?
#
#  1:  É no momento da constituição que a inscrição da sociedade nas finanças, na segurança social e noutros serviços públicos deve ser feita?
#
#  2:  Aquando a constituição, deve ser feita a inscrição da sociedade nas finanças, na segurança social e noutros serviços públicos?
#
#  3:  Deve a inscrição da sociedade nas finanças, na segurança social e noutros serviços públicos ser feita no momento da constituição?
#
#  ID to return: 31
#
#  Answer:  		A Conservatória disponibiliza informaticamente os dados necessários para efeitos de inscrição do início de actividade à Direcção-Geral dos Impostos, à Autoridade para as Condições do Trabalho e aos serviços de Segurança Social.
#
#
#  0:  Será possível utilizar o processo de constituição da Empresa Online quando os sócios são pessoas colectivas? E se forem pessoas colectivas estrangeiras, existe algum formalismo prévio?
#
#  1:  Sendo os sócios pessoas colectivas, é possível utilizar o processo de constituição da Empresa Online? E caso estes sejam pessoas colectivas estrangeiras, há algum formalismo extra?
#
#  2:  O processo de constituição da Empresa Online está disponível quando os sócios são pessoas colectivas? Há algumas regras adicionais caso estes sejam pessoas colectivas?
#
#  3:  Caso os sócios sejam pessoas colectivas, será possível utilizar o processo de constituição da Empresa Online? E sendo estes pessoas colectivas estrangeiras, o processo altera-se?
#
#  ID to return: 32
#
#  Answer: 	   Não existe qualquer tipo de impedimento, quer os sócios da sociedade a constituir sejam pessoas colectivas nacionais ou estrangeiras. Contudo, as pessoas colectivas estrangeiras devem ser detentoras de número de identificação de entidade equiparada emitido pelo RNPC (consulte as perguntas frequentes do RNPC no site do IRN).
#
#
#  0:  Será possível, a cidadãos estrangeiros, a constituição de uma Empresa Online? Nestes casos, existe algum formalismo prévio que deva ser respeitado?
#
#  1:  Cidãdãos estrangeiros podem constituir uma Empresa Online? Se assim for, deve ser respeitado algum formalismo?
#
#  2:  A constituição de uma Empresa Online é possível para cidadão estrangeiros? Sendo assim, que formalismo prévio tem de ser respeitado?
#
#  3:  É possível a constituição de uma Empresa Online para cidadãos estrangeiros? Qual o formalismo prévio a ser respeitado?
#
#  ID to return: 33
#
#  Answer:        Não existe impedimento legal à participação de cidadãos estrangeiros na constituição de sociedades em Portugal. Contudo, existe um requisito prévio que se consubstancia na exigência legal da titularidade, à data da constituição da sociedade, de um número de identificação fiscal emitido pelos Serviços de Finanças de Portugal.
#
#
#  0:  É possível indicar um Técnico Oficial de Contas (TOC) no momento da constituição da Empresa Online?
#
#  1:  Um Técnico Oficial de contas (TOC) pode ser indicado no momento da constituição da Empresa Online?
#
#  2:  No momento da constituição da Empresa Online pode ser indicado um Técnico Oficial de Contas (TOC)?
#
#  3:  Quando se dá a constituição da Empresa Online é possível que seja indicado um Técnico Oficial de Contas (TOC)?
#
#  ID to return: 34
#
#  Answer:        Sim. Estão disponíveis as seguintes opções:
#          Indicar um TOC introduzindo directamente os dados do mesmo;
#          Seleccionar um TOC da respectiva bolsa, disponibilizado pela Câmara dos TOC (CTOC) (i16). Este será atribuído com base na indicação do Distrito, Concelho e Código Postal (Freguesia). O valor máximo a ser cobrado pelo TOC, para preenchimento e entrega da declaração de inicio de actividade, é de € 50, acrescendo de IVA à taxa legal em vigor;
#          Não indicar nenhum TOC e optar por se dirigir à Administração Fiscal no prazo de 15 dias para apresentar a declaração de início de actividade.
#        A vantagem da indicação do TOC no momento da constituição é a de permitir que o mesmo tenha legitimidade para apresentar via Internet a declaração de início de actividade.
#
#
#  0:  Qual é o website onde irão ser feitas as publicações?
#
#  1:  As publicações serão feitas em qual website?
#
#  2:  Qual é o endereço online onde apareceram as publicações?
#
#  3:  Onde é que posso aceder, de forma online às publicações?
#
#  ID to return: 35
#
#  Answer:        As publicações fazem-se, automaticamente, através do sítio da Internet de acesso público Publicações.
#
#
#  0:  Qual o prazo que a Conservatória tem para efectuar o registo?
#
#  1:  O registo será efetuado pela Conservatória até quando?
#
#  2:  Em que data é que é dado o registo pela Conservatória?
#
#  3:  Quando é que a Conservatória irá realizar o registo?
#
#  ID to return: 36
#
#  Answer:        Não existindo inconformidades no processo de constituição, a Conservatória procede de imediato ao registo, quando se tratar de um pacto pré-aprovado, ou no prazo de dois dias úteis caso se trate de um pacto elaborado pelos próprios interessados.
#
#
#
#  0:  Como recebo o Cartão da Empresa?
#
#  1:  Como é que será remetido o Cartão da Empresa?
#
#  2:  Quanto ao Cartão da Empresa, como é que o recebo?
#
#  3:  Como é que terei acesso ao Cartão da Empresa?
#
#  ID to return: 37
#
#  Answer:        Se o registo ficar desde logo definitivo, a conservatória remete o Cartão da Empresa via postal, directamente para a sede da sociedade. Logo que concluído o registo, a conservatória comunica o código de acesso ao Cartão Electrónico da Empresa.
#
#
#  0:  Quais as vantagens de aderir a um centro de arbitragem?
#
#  1:  O que é que tenho a ganhar ao aderir a um centro de arbitragem?
#
#  2:  Qual é a utilidade da adesão a um centro de arbitragem?
#
#  3:  Relativamente à aderência de um centro de arbitragem, quais as suas vantagens?
#
#  ID to return: 38
#
#  Answer:        Ao aderir a um centro de arbitragem, a empresa aceita a intervenção deste em eventuais conflitos de que possam surgir e que se insiram no âmbito da competência do centro. Após a recepção da reclamação e a sua análise por um jurista do centro, procede-se sempre a uma tentativa de mediação, visando estabelecer um acordo entre as partes. Caso a mediação não resulte, o processo será encaminhado para a conciliação e arbitragem.
#
#        Após a comunicação da Sede do estabelecimento comercial, o centro entrega um dístico autocolante que o empresário se obriga a colocar em local visível, permitindo que os consumidores identifiquem o estabelecimento como aderente ao centro de arbitragem.
#
#        As empresas que efectuam a adesão plena e imediata passam a constar da listagem de estabelecimentos aderentes ao centro de arbitragem, divulgada publicamente pelos meios mais adequados.
#
#        O processo de adesão é simples, voluntário e não implica qualquer custo, basta preencher o formulário “adesão plena e imediata” disponível no processo da constituição da Empresa Online.
#
#
#
#  0:  Existe alguma especificidade quanto a aos CAE's escolhidos?
#
#  1:  Quanto aos CAE's escolhidos, existe alguma especificidade?
#
#  2:  Existe alguma exceção no que toca aos CAE's selecionados?
#
#  3:  Relativamente aos CAE's selecionados, existe alguma exceção?
#
#  ID to return: 39
#
#  Answer:        Apenas as CAE’s 34 e 50 (referidas na tabela dos CAE’s como veículos automóveis) deverão ser “assinaladas” para efeitos do Centro de Arbitragem do Sector Automóvel (têm competência para todo o território nacional).
#        As restantes CAE’s dizem respeito aos restantes centros (uma vez que a competência material destes é idêntica).
#
#
#  0:  O que é um Certificado Digital?
#
#  1:  Em que consiste um Certificado Digital?
#
#  2:  Que informações existem acerca do Certificado Digital?
#
#  3:  Que mais posso saber do Certificado Digital?
#
#  ID to return: 40
#
#  Answer:        Um certificado digital pode ser utilizado como forma de identificação digital, como se de um bilhete de identidade electrónico se tratasse. Pode ser igualmente utilizado para efectuar transacções electrónicas com segurança ou assinar digitalmente documentos.
#
#        Graças aos certificados digitais, uma transacção electrónica realizada via Internet torna-se perfeitamente segura, pois permite que as partes envolvidas apresentem, cada uma, as suas credenciais para comprovar, à outra parte, a sua real identidade.
#
#
#  0: Sou advogado e já tenho um certificado digital que integra a minha cédula profissional, posso utilizar este certificado para me autenticar e utilizar o serviço de criação de empresa?
#
#  1: Sendo advogado, posso utilizar o certificado digital que integra a minha cédula profissional para me autenticar e utilizar o serviço de criação de empresa?
#
#  2: É possivel utilizar o certificado digital que integra a minha cédula profissional de advogado para me autenticar e utilizar o serviço de criação de empresas?
#
#  3: Posso utilizar o certificado digital que integra a minha cédula proffisional de advogado para me autenticar e utilizar o serviço de criação de empresas?
#
#  ID to return: 41
#
#  Answer:         Sim, o certificado da cédula profissional de advogado pode ser utilizado no serviço de criação de empresas online. Para utilizar este certificado deve, contudo, verificar se o mesmo se encontra plenamente válido.
#
#
#  0: Que tipo de certificado é que pode ser utilizado no processo de criação de empresa?
#
#  1: No processo de criação de empresa, que tipo de certificado é que pode ser utilizado?
#
#  2: Quais os certificados que podem ser utilizados no processo de criação de empresa?
#
#  3: Que certificados podem ser usados no processo de criação de empresa?
#
#  ID to return: 42
#
#  Answer:         Os advogados, solicitadores e notários podem usar qualquer certificado digital que ateste a respectiva qualidade profissional. Os cidadãos portadores do Cartão de Cidadão estão certificados mediante esse mesmo documento de identificação.
#
#
#  0: O que é um certificado digital qualificado?
#
#  1: Quais as características de um certificado digital qualificado?
#
#  2: Qual é a definição de um certificado digital qualificado?
#
#  3: O que caracteriza um certificado digital qualificado?
#
#  ID to return: 43
#
#  Answer:         O certificado digital é um documento electrónico que liga os dados de verificação de assinatura ao seu titular e confirma a identidade desse titular. Para ser qualificado, o certificado digital tem de ser emitido por uma entidade certificadora credenciada. Este tipo de certificado quando utilizado para assinar um documento electrónico equivale, para efeitos legais, a uma assinatura manuscrita.
#
#
#  0: Onde posso adquirir um certificado digital qualificado?
#
#  1: Em que sitios posso adquirir um certificado digital qualificado?
#
#  2: Em que locais posso adquirir um certificado digital qualificado?
#
#  3: Como posso adquirir um certificado digital qualificado?
#
#  ID to return: 44
#
#  Answer:         Os certificados digitais são emitidos por empresas certificadoras. Em Portugal já há algumas empresas a prestar este serviço. No entanto, os certificados digitais a utilizar na Empresa Online são obrigatoriamente certificados digitais qualificados. Ou seja, a entidade que emite o certificado terá de estar credenciada junto da entidade responsável pela credenciação de empresas certificadoras.
# O acesso à informação pessoal no Portal da Empresa é feito apenas pela Dossier Electrónico da Empresa, para o efeito é utilizado certificado digital. De momento, apenas advogados, solicitadores e notários e os cidadãos portadores do Cartão de Cidadão podem recorrer a este serviço, uma vez que possuem certificados digitais integrados nas respectivas cédulas profissionais ou no novo documento de identificação.
#
#
#  0: O meu pacto social digitalizado não se encontra muito legível. Que devo fazer?
#
#  1: O que devo fazer no caso de o meu pacto social digitalizado não se encontrar muito legível?
#
#  2: No caso de o meu pacto social digitalizado não se encontrar muito legivel, o que devo fazer?
#
#  3: O meu pacto social digitalizado encontra-se pouco legivel. Que devo fazer?
#
#  ID to return: 45
#
#  Answer:         Verifique se o original se encontra legível e apresenta um bom contraste. Caso o original esteja esbatido, ajuste os parâmetros de impressão (escolha o que resulta numa maior qualidade). Verifique também se a impressora necessita de substituir os consumíveis (tinteiros ou tonner );
# No programa de digitalização escolha as opções correspondentes a uma qualidade de 100 dpi ou 200 dpi (dots per inch ou pontos por polegada).
# No software de digitalização escolha um tipo de digitalização correspondente a “preto e branco” ou “níveis de cinzento” – não é conveniente a digitalização a cores. Nota: alguns programas referem- se a este tipo de digitalização como “texto” ou line-art .
#
#
#  0: A assinatura não se encontra legível. Que posso fazer?
#
#  1: O que posso fazer no caso de a assinatura não se encontrar muito legível?
#
#  2: No caso de a assinatura não se encontrar légivel, o que posso fazer?
#
#  3: A assinatura encontra-se pouco legível. Que posso fazer?
#
#  ID to return: 46
#
#  Answer:         Use tinta preta ou muito escura para assinar os documentos a digitalizar e verifique a qualidade do documento digitalizado. Comprove que o mesmo se encontra legível antes do seu envio para o Portal da Empresa.
#
#
#  0: O Cartão de Cidadão pode ser utilizado no processo de criação da empresa online?
#
#  1: No processo de criação da empresa online, pode ser utilizado o Cartão de Cidadão?
#
#  2: Ao criar a empresa online, pode ser utilizado o cartão de cidadão?
#
#  3: Posso utilizar o Cartão de Cidadão na criação da empresa online?
#
#  ID to return: 47
#
#  Answer:         Sim, o Cartão de Cidadão tem um certificado digital, que pode ser utilizado para constituir empresas online.
#
#
#  0:  Como posso enviar o Pacto Social e o anexo de reconhecimento para o Portal da Empresa?
#
#  1:  De que formas posso enviar o Pacto Social e o anexo de reconhecimento para o Portal da Empresa?
#
#  2:  Como devo proceder para enviar o Pacto Social e o anexo de reconhecimento para o Portal da Empresa?
#
#  3:  O que fazer para enviar o Pacto Social e o anexo de reconhecimento para o Portal da Empresa?
#
#  ID to return: 48
#
#  Answer:         As páginas do pacto social e do anexo de reconhecimentos devem ser digitalizados num só documento. Consulte as opções do seu programa de digitalização para obter este resultado. Caso o software não suporte esta funcionalidade, envie as páginas digitalizadas em separado indicando o número da página na respectiva descrição. Por exemplo: “Pacto Social e Anexo de Reconhecimentos – pág. 1 de 5”.
#
#
#  0: Um cidadão estrangeiro pode constituir uma empresa através do serviço de criação de Empresa Online?
#
#  1: É possivel um cidadão estrangeiro constituir uma empresa através do serviço de criação de Empresa Online?
#
#  2: Pode um cidadão estrangeiro constituir uma empresa através do serviço de criação de Empresa Online?
#
#  3: O serviço de criação de empresa Online permite que um cidadão estrangeiro constitua uma empresa?
#
#  ID to return: 49
#
#  Answer:           Sim. Cidadãos estónios e espanhóis podem criar uma empresa online recorrendo ao certificado do seu documento nacional de identificação.
#
# Documento:
#
#
#
#  0: O que é uma certidão permanente?
#
#  1: Qual a definição de certidão permanente?
#
#  2: O que define uma certidão permanente?
#
#  3: Em que consiste uma certidão permanente?
#
#  ID to return: 50
#
#  Answer:
# 				É o acesso, através da Internet, em tempo real e em qualquer momento, a todos os registos, a
# 				todos os documentos eletrónicos ou ao último pacto social / estatutos atualizados, de uma entidade
# 				registada em conservatória do registo comercial (sociedades, cooperativas, empresas públicas e
# 				outras entidades sujeitas a registo comercial), consoante o tipo de certidão subscrita.
#
#
#  0: Como posso ter acesso a uma certidão permanente?
#
#  1: Como aceder a uma certidão permanente?
#
#  2: Como é possível aceder a uma certidão permanente?
#
#  3: De que maneira posso aceder a uma certidão permanente?
#
#  ID to return: 51
#
#  Answer:
# 				Fazendo um pedido de subscrição, pelo prazo de um, dois, três ou quatro anos. Ao subscrever este
# 				serviço é-lhe atribuído, de imediato, um código de acesso à certidão permanente.
#
#
#  0: Onde posso pedir uma certidão permanente?
#
#  1: Em que local posso pedir uma certidão permanente?
#
#  2: Onde pedir certidão permanente?
#
#  3: Onde me posso dirigir para pedir uma certidão permanente?
#
#  ID to return: 52
#
#  Answer:
# 				Na Internet, em qualquer um dos seguintes endereços:
# 					- No Portal da Empresa;
# 					- Na Empresa Online;
# 					- No Portal da Justiça;
# 					- No Portal do Cidadão.
# 				ou em qualquer conservatória do registo comercial.
#
#
#  0: Quem pode pedir uma certidão permanente online?
#
#  1: Posso pedir uma certidão permanente online?
#
#  2: Quem é elegível para o pedido de uma certidão permanente online?
#
#  3: Qualquer pessoa pode pedir uma certidão permanente online?
#
#  4: Condições para pedir uma certidão permanente online?
#
#  ID to return: 53
#
#  Answer:
# 				Qualquer pessoa poderá efectuar o pedido de uma certidão permanente online . Não existe
# 				qualquer tipo de autenticação para utilizar este serviço.
#
#
#  0: Quais as vantagens de subscrever uma certidão permanente?
#
#  1: Quais as vantagens de pedir uma certidão permanente?
#
#  2: O que ganho em pedir uma certidão permanente?
#
#  3: Benefícios de pedir uma certidão permanente?
#
#  4: Porque pedir uma certidão permanente?
#
#  5: Razões para pedir uma certidão permanente?
#
#  6: O que dá o pedido de uma certidão permanente?
#
#  7: Porque requerer uma certidão permanente?
#
#  ID to return: 54
#
#  Answer:
# 				Sempre que necessitar de uma certidão não precisa de ir a uma conservatória. Bastar-lhe-á
# 				entregar o código de acesso à entidade requerente, para consulta online.
#
#
#  0: Qual a informação que consta de uma certidão permanente?
#
#  1: O que consta numa certidão permanente?
#
#  2: Que informação posso encontrar numa certidão permanente?
#
#  3: O que tem uma certidão permanente?
#
#  4: qual o conteúdo de uma certidão permanente?
#
#  ID to return: 55
#
#  Answer:
# 				A certidão permanente de registo contém todos registos da entidade e todos os pedidos de registo
# 				por transcrição ou por depósito, ainda pendentes de elaboração ou confirmação, sendo que
# 				relativamente a estes é disponibilizada informação sobre o número da apresentação e/ou do
# 				depósito pendentes com a identificação do tipo de atos requeridos.
#
# 				A certidão permanente de registo e documentos contém todos registos da entidade e todos os
# 				pedidos de registo por transcrição ou por depósito, ainda pendentes de elaboração ou confirmação,
# 				sendo que relativamente a estes é disponibilizada informação sobre o número da apresentação
# 				e/ou do depósito pendentes com a identificação do tipo de atos requeridos, permitindo ainda a
# 				visualização de todos os documentos associados à pasta eletrónica da entidade, com exceção dos
# 				documentos da prestação de contas.
#
# 				A certidão permanente do pacto social / estatutos atualizados permite a visualização do último
# 				pacto social / estatutos atualizados, associados à pasta eletrónica da entidade.
#
#
#  0: Posso imprimir a certidão permanente?
#
#  1: Devo imprimir a certidão permanente?
#
#  2: Preciso de imprimir a certidão permanente?
#
#  3: É possível imprimir a certidão permanente?
#
#  4: É obrigatório imprimir a certidão permanente?
#
#  ID to return: 56
#
#  Answer:
# 				Apesar de poder imprimir a certidão permanente, a impressão da informação não tem o valor
# 				jurídico de certidão e não substitui a consulta da certidão permanente no sítio da Internet.
#
#
#  0: A partir de e até quando posso renovar a certidão permanente?
#
#  1: Quais os prazos para a renovação da certidão permanente?
#
#  2: Qual a validade da certidão permanente?
#
#  3: Quando preciso de renovar a certidão permanente?
#
#  ID to return: 57
#
#  Answer:
# 				Não poderão ser renovadas assinaturas de certidões permanentes cujo prazo de validade tenha
# 				expirado, ficando o respetivo código de acesso automaticamente desativado exceto para aquelas
# 				que estejam com um pedido de renovação pendente (sem pagamento confirmado), que ainda
# 				poderão ser visualizadas até um prazo máximo de cinco dias.
#
#
#  0: E se não me lembrar da data do fim de validade da certidão?
#
#  1: O que acontece se me esquecer de renovar a certidão permanente?
#
#  2: E se me esquecer da data do fim de validade da certidão?
#
#  3: Sou notificado relativamente ao prazo de validade da certidão?
#
#  ID to return: 58
#
#  Answer:
# 				De modo a alertar o requerente do fim do prazo de validade da certidão permanente serão
# 				enviadas, por e-mail, três notificações: 30 dias antes, sete dias antes e um dia antes.
#
#
#  0: Ao renovar a minha certidão vou ter um novo código de acesso?
#
#  1: Quando renovar a minha certidão recebo outro código de acesso?
#
#  2: Ao renovar a minha certidão recebo outro código de acesso?
#
#  3: O código é permanente no caso de renovação da certidão?
#
#  4: O código é permanente ao renovar a certidão?
#
#  5: Renovar a minha certidão resulta em mudança do código de acesso?
#
#  ID to return: 59
#
#  Answer:
# 				Nas renovações, o código de acesso à certidão permanente mantém-se.
#
#
#  0: O que é a extratação de uma entidade?
#
#  1: Em que consiste uma extratação de uma entidade?
#
#  2: O que significa extratação de uma entidade?
#
#  3: Qual a definição de extratação de uma entidade?
#
#  ID to return: 60
#
#  Answer:
# 				A extratação de uma entidade corresponde à introdução dos dados, constantes dos registos em
# 				papel, na aplicação informática de suporte à atividade de registo comercial.§
#
#
#  0: Quanto tempo poderá levar a extractar uma entidade?
#
#  1: Quanto tempo demora a extractar uma entidade?
#
#  2: Tempo que a extratação de uma entidade demora?
#
#  3: Qual a duração de tempo associada a uma extratação de uma entidade?
#
#  4: Qual o período de tempo associada a uma extratação de uma entidade?
#
#  5: Qual a duração de uma extratação de uma entidade?
#
#  ID to return: 61
#
#  Answer:
# 				Para as entidades cuja informação não se encontra totalmente informatizada, o prazo de
# 				disponibilização da certidão será de dois dias úteis.
#
#
#  0: Qual o custo de uma certidão permanente e quais as modalidades de pagamento?
#
#  1: Quanto custa uma certidão e como posso pagá-la?
#
#  2: Quanto custa uma e como posso pagar uma certidão permanente?
#
#  3: Qual o valor de uma certidão permanente?
#
#  4: Qual o preço de uma certidão permanente?
#
#  5: Como posso pagar uma certidão permanente?
#
#  6: Métodos de pagamento de certidão permanente?
#
#  ID to return: 62
#
#  Answer:
# 				O custo da certidão permanente é o seguinte:
# 					- Assinatura por um ano - € 25,00;
# 					- Assinatura por dois anos - € 40,00;
# 					- Assinatura por três anos - € 60,00;
# 					- Assinatura por quatro anos - € 70,00.
#
# ...
#
#  2: Quando é feita a comunicação de abertura de um empreendimento turístico deve ser entregue a ficha de segurança contra riscos de incêndio?
#
#  3: Apara comunicação de abertura de um empreendimento turístico é necessário entregar a ficha de segurança contra riscos de incêndio?
#
#  ID to return: 601
#
#  Answer: 					Não. A ficha de segurança contra riscos de incêndio, que decorre do n.o 2 do Art. 17.o do Decreto-Lei n.o 220/208, de 12 de novembro, deve acompanhar o projeto de arquitetura, sendo considerada no momento da atribuição da autorização de utilização.
# 					Para qualquer processo decorrente do licenciamento de uma operação urbanística, a ficha deverá ser preenchida por engenheiros, engenheiros técnicos ou arquitetos, de acordo com o próprio RJUE. Para edifícios/recintos das 3.a e 4.a categorias de risco, impõe-se a obrigatoriedade de que estas fichas sejam preenchidas por técnicos credenciados, inscritos na ANPC (n.o 1, artigo 16.o).
# 					Caso o edifício não possua autorização de utilização, e não tenham sido realizadas obras consideradas operações urbanísticas, o interessado apenas terá que entregar documentos referentes às medidas de autoproteção, de acordo com a “utilização tipo” e a categoria de risco em causa.
#
# Documento:
#
#
#
#  0: A realização de leilões em espaço público também passou a ser dispensada de licença de ocupação de espaço público?
#
#  1: Já não é necessário licença de ocupação de espaço público para a realização de leilões em espaço público?
#
#  2: Deixou de ser preciso licença de ocupação de espaço público para a realização de leilões em espaço público?
#
#  3: É possível realizar leilões em espaço público sem a licença de ocupação de espaço público?
#
#  ID to return: 602
#
#  Answer: 					Não. O Licenciamento Zero veio eliminar apenas a necessidade de ser solicitada à câmara municipal a licença para realização de leilões em lugares públicos.
# 					Contudo, mantém-se a necessidade de ser pedida previamente a licença de ocupação de espaço público à respetiva autarquia, uma vez que o espaço público, entendido como ruas, praças e passeios de acesso livre ao público, é gerido pela câmara municipal.
#
# Documento:
#
#
#
#  0: O que é a Ordem dos Engenheiros?
#
#  1: O que significa "Ordem dos Engenheiros"?
#
#  2: Qual é a associação pública representativa dos engenheiros?
#
#  3: Qual a Ordem dos profissionais de engenharia?
#
#  ID to return: 603
#
#  Answer: 					A Ordem dos Engenheiros é a associação pública representativa dos licenciados em Engenharia que exercem a profissão de engenheiro. Tem como objetivo contribuir para o progresso da engenharia, estimulando os esforços dos seus associados nos domínios científico, profissional e social, bem como o cumprimento das regras de ética profissional.
#
#
#  0: O que é a Ordem dos Médicos Veterinários?
#
#  1: O que significa "Ordem dos Médicos Veterinários"?
#
#  2: Qual é a associação pública representativa dos Médicos Veterinários?
#
#  3: Qual a Ordem dos profissionais de medicina veterinária?
#
#  ID to return: 604
#
#  Answer: 					A Ordem dos Médicos Veterinários é a instituição representativa dos licenciados em Medicina Veterinária ou equiparados legais que, em conformidade com os preceitos deste Estatuto e demais disposições legais aplicáveis, exercem atividades veterinárias.
#
# Documento:
#
#
#
#  0: O que é um fornecedor de plantas hortícolas ou de materiais frutícolas?
#
#  1: O que se entende por fornecedor de plantas hortícolas ou de materiais frutícolas?
#
#  2: Qual a definição de fornecedor de plantas hortíolas ou de materiais frutícolas?
#
#  3: O que caracteriza um fornecedor de plantas hortícolas ou de materiais frutícolas?
#
#  ID to return: 605
#
#  Answer: 					É uma pessoa singular ou coletiva, pública ou privada, que dispõe dos meios adequados e procede à conservação, beneficiação e comercialização de plantas hortícolas ou materiais frutícolas adquiridos a outrem.
#
#
#  0: O que é uma planta-mãe?
#
#  1: O que signifca planta-mãe?
#
#  2: Qual é a definição de planta-mãe?
#
#  3: Qual o significado de planta-mãe?
#
#  ID to return: 606
#
#  Answer: 					É a cultura de plantas da mesma categoria, variedade e espécie, destinada à produção de sementes, estacas, garfos ou plantas.
#
#
#  0: O que se entende por clone?
#
#  1: O que é um clone na prática hortícola?
#
#  2: A que se refere o termo "clone"?
#
#  3: O que significa "clone"?
#
#  ID to return: 607
#
#  Answer: 					Clone é descendência vegetativa de variedade de uma espécie de fruteiras, obtida a partir de uma planta selecionada pela sua identidade varietal, os seus caracteres fisiológicos e o seu estado sanitário.
#
# Documento:
#
#
#
#  0: Estou desempregrado. Pretendo criar o meu próprio emprego. O IEFP tem apoios para a minha situação?
#
#  1: Não tenho emprego e quero criar a minha própria empresa. Há apoios do Governo?
#
#  2: Há apoios do IEFP para quem se encontra desempregado e quer criar o seu próprio emprego?
#
#  3: Não tenho emprego e quer criar o meu próprio negócio. Há alguma ajuda governamental?
#
#  ID to return: 608
#
#  Answer:                 O IEFP dispões, com efeito, de um conjunto de apoios, técnicos, financeiros e até logísticos para desempregados que pretendam criar o seu próprio emprego ou empresa.
#                 Se for beneficiário de prestações de desemprego pode ainda candidatar-se a apoios específicos que lhe são proporcionados no âmbito do Programa de Estímulo à Oferta de Emprego.
#                 Para mais informações, bem como um aconselhamento mais personalizado, poderá deslocar-se ao Centro de Emprego da sua área de residência, onde uma equipa técnica multidisciplinar o acompanhará na construção e concretização de um projecto empresarial sólido e com hipótese de viabilidade, encaminhando-o para a solução que se revele mais adequada ao seu caso.
#
#
#  0: Sou jovem e nunca estive empregado. Gostaria de criar a minha própria empresa. O IEFP pode ajudar-me?
#
#  1: Nunca tive emprego, sou jovem e quero criar a minha empresa. Há apoios do IEFP?
#
#  2: Há ajudas do IEFP para jovens que nunca tenham estado empregados que desejem começar a sua própria empresa?
#
#  3: O IEFP possui apoios para jovens que nunca tenham trabalhado interessados em criar o seu próprio negócio?
#
#  ID to return: 609
#
#  Answer:                 O IEFP dispõe, com efeito, de um conjunto de apoios, técnicos, financeiros e até logísticos para os jovens à procura do primeiro emprego que pretendam criar o seu próprio emprego ou empresa.
#                 Para mais informações, bem como um aconselhamento mais personalizado, poderá deslocar-se ao Centro de Emprego da sua área de residência, onde uma equipa técnica multidisciplinar o acompanhará na construção e concretização de um projecto empresarial sólido e com hipótese de viabilidade.
#
#
#  0: Sou beneficiário do subsídio de desemprego, mas gostaria de abrir o meu próprio negócio. O IEFP tem algum apoio específico para a minha situação?
#
#  1: Há programas específicos do IEFP para quem receba subsídio de desemprego e queira abrir a sua própria empresa?
#
#  2: Recebo o subsídio de desemprego mas desejo criar uma empresa. O IEFP possui apoios para este caso?
#
#  3: O IEFP tem algum apoio específico para quem deseja criar o seu próprio negócio mas receba o subsídio de desemprego?
#
#  ID to return: 610
#
#  Answer:                 No âmbito do Programa de Estímulo à Oferta de Emprego, o IEFP pode proporcionar apoios específicos a projectos de criação de emprego promovidos por beneficiários de prestações de desemprego.
#                 Para mais informações, bem como um aconselhamento mais personalizado, contacte o Centro de Emprego da sua área de residência, onde encontrará apoio especializado na construção e concretização de um projecto empresarial sólido e com hipótese de viabilidade e o encaminhamento para a solução mais adequada ao seu caso.
#
#
#  0: Pretendo constituir uma Empresa de Trabalho Temporário (ETT). Como devo proceder?
#
#  1: Como devo proceder para abrir uma Empresa de Trabalho Temporário (ETT)?
#
#  2: Qual é o procedimento para constituir uma Empresa de Trabalho Temporário (ETT)?
#
#  3: Quero abrir uma Empresa de Trabalho Temporário (ETT). Como é suposto proceder?
#
#  ID to return: 611
#
#  Answer:                 1.º Passo: Constituição da empresa nos termos legais (sociedades comerciais ou empresários em nome indivídual)
#                 De acordo com o regime jurídico do trabalho temporário (Decreto-Lei nº 358/89, de 17 de Outubro, com redacção dada pela Lei nº 146/99, de 1 de Setembro), são requisitos essenciais, nesta fase, que:
#                   o certificado de admissibilidade da firma, a requerer junto do Registo Nacional de Pessoas (RNPC), mencione obrigatoriamente a expressão "empresa de trabalho temporário";
#                   o objecto social da empresa, caso se trate de sociedade comercial (por quotas, unipessoal ou anónima), ou o ramo de actividade do empresário em nome individual, traduza de forma inequívoca que se trata de "cedência temporária de trabalhadores para utilização de terceiros utilizadores";
#                   No cartão de identificação de pessoa colectiva, conste o código de CAE 74500.
#                 2.º Passo: Processo de autorização a conceder através do IEFP
#                 O pedido de autorização é apresentado no Centro de Emprego da área da sede da empresa, que faculta ao requerente as minutas do requerimento e demais declarações a apresentar, bem como a indicação de outros documnetos necessários à instrução do processo. Estas minutas podem também ser obtidas no portal do IEFP.
#                 As Empresas de Trabalho Temporário regularmente constituídas só podem iniciar a sua actividade depois de obterem a autorização e o respectivo Alvará.
#
#
#  0: Que requisitos devo preencher, em termos de capacidades técnicas, para exercer funções como Director Técnico de uma Empresa de Trabalho Temporário?
#
#  1: Que capacidades técnicas devo ter para, numa Empresa de Trabalho Temporário, exercer funções de Director Técnico?
#
#  2: Para exercer o cargo de Director Técnico numa Empresa de Trabalho Temporário, que capacidades técnicas são necessárias?
#
#  3: No que toca a capacidades técnicas, quais são os requisitos para poder exercer funções como Director Técnico de uma Empresa de Trabalho Temporário?
#
#  ID to return: 612
#
#  Answer:                 A capacidade técnica das Empresas de Trabalho Temporário traduz-se na existência de um Director Técnico que possua habilitações profissionais adequadas e experiência de gestão de recursos humanos e de suporte administrativo e organizacional necessário à gestão. Os documentos que comprovam a capacidade técnica são o curriculum vitae do Director Técnico e o respectivo certificado de registo criminal.
#                 Estes documentos podem ser apresentados com o requerimento ou em fase posterior, num prazo de 30 dias depois de concedida a autorização. Caso não sejam apresentados com o requerimento, são substituídos por uma declaração sob compromisso de honra em como a empresa cumprirá este requisito nos 30 dias posteriores à concessão da autorização.
#
#
#  0: Para poder funcionar, a minha Empresa de Trabalho Temporário tem de constituir uma caução a favor do IEFP. Para que serve essa caução e qual o seu valor?
#
#  1: Qual o valor e a função da caução que as Empresas de Trabalho Temporário têm de pagar ao IEFP?
#
#  2: A minha Empresa de Trabalho Temporário tem de constituir uma caução a favor do IEFP para poder funcionar. Qual o valor e função desta caução?
#
#  3: Uma Empresa de Trabalho Temporário necessita de constituir uma caução a favor do IEFP para poder funcionar. Esta caução serve que propósito e qual o seu valor?
#
#  ID to return: 613
#
#  Answer:                 As Empresas de Trabalho Temporário constituem obrigatoriamente uma caução a favor do IEFP, que se destina a garantir a sua responsabilidade pelo pagamento das remunerações e demais encargos com os trabalhadores temporários. A caução pode ser prestada por depósito, garantia bancária ou contrato de seguro, e o seu valor corresponde a:
#                 200 x remuneração mínima mensal garantida mais elevada x taxa contributiva global (34,75%), devendo ser anualmente actualizada até 31 de Janeiro, ou até 30 dias após a publicação do diploma de revisão da remuneração mínima mensal garantida.
#                 O montante da caução para o ano de 2006 é de € 104.000,05.
#
# Documento:
#
#
#
#  0: Qual é a definição nacional de Pequena e Média Empresa (PME)?
#
#  1: Qual é a definição portuguesa de uma Pequena e Média Empresa (PME)?
#
#  2: Como se define uma Pequena e Média Empresa (PME) em Portugal?
#
#  3: Como se define nacionalmente uma Pequena e Média Empresa (PME)?
#
#  ID to return: 614
#
#  Answer:                 De acordo com a definição nacional (Despachos Normativos nº 52/87, nº 38/88 e Aviso constante do DR nº 102/93, Série III), são PME as empresas que, cumulativamente, preencham os seguintes requisitos:
#                   Empreguem até 500 trabalhadores (600, no caso de trabalho por turnos regulares);
#                   Não ultrapassem 11.971.149 euros de vendas anuais;
#                   E não possuam nem sejam possuídas em mais de 50% por outra empresa que ultrapasse qualquer dos limites definidos nos pontos anteriores.
#                 De notar que nesta definição são apenas apresentados critérios de classificação de pequenas e médias empresas, não se distinguindo, de entre estas, micro, pequenas e médias empresas.
#                 Contudo, apesar de ser esta a definição em vigor em Portugal, a verdade é que, na prática, na maioria das situações, e designadamente para efeitos de atribuição de incentivos no âmbito do POE, estão a ser considerados os critérios constantes da "definição europeia" (Recomendação da Comissão (2003/361/CE, de 6 de Maio), por motivos que se prendem com a necessidade de harmonização de conceitos no seio da União Europeia.
#
#
#  0: Qual a definição europeia de Micro, Pequena e Média Empresa (PME)?
#
#  1: A nível europeu, como se define Micro, Pequena e Média Empresa (PME)?
#
#  2: Qual a definição de Micro, Pequena e Média Empresa (PME) a nível europeu?
#
#  3: Na Europa, qual a definição de Micro, Pequena e Média Empresa (PME)?
#
#  ID to return: 615
#
#  Answer:                 Entende-se por Micro, Pequena e Média Empresa (PME), segundo a Recomendação da Comissão 2003/361/CE, de 6 de Maio de 2003, aquela que:
#                 Categoria N.º Trabalhores Volume de Negócios Balanço Total Média Empresa < 250 < = 50 Milhões de euros < = 43 Milhões de euros Pequena Empresa < 50 < = 10 Milhões de euros < = 10 Milhões de euros Microempresa < 10 < = 2 Milhões de euros < = 2 Milhões de euros
#                 Relativamente ao método de cálculo dos limiares:
#                   Para uma empresa autónoma, os dados financeiros e relativos aos efectivos são baseados unicamente nas contas dessa empresa;
#                   Para uma empresa que tenha empresas parceiras ou associadas, os dados financeiros relativos aos efectivos são baseados nas contas e outros dados da empresa (ou nas contas consolidadas quando existam). A estes dados devem agregar-se os dados das empresas parceiras - numa base proporcional à percentagem de participação no capital (ou à percentagem de direitos de voto, se esta for superior) - e 100% dos dados das empresas associadas.
#                 A aplicação desta definição é vinculativa em matéria de aplicação dos fundos estruturais europeus e dos programas comunitátios, em especial a todas as candidaturas no âmbito do PRIME entradas a partir de 1 de Janeiro de 2005 e ao 6.º Programa-Quadro de Investigação.
#                 A Comissão Europeia recomenda aos Estados-Membros, ao BEI (Banco Europeu de Investimento) e ao FEI (Fundo Europeu de Investimento) que apliquem uma definição comum de Micro, Pequenas e Médias Empresas. No entanto, os Estados-Membros e as duas instituições financeiras não são obrigados a respeitar esta definição.

# %%
streetno = {"1": "Sachine Tendulkar",
            "2": "Dravid",
            "3": "Sehwag",
            "4": "Laxman",
            "5": "Kohli" }
streetno["1"]
# Out:
# 'Sachine Tendulkar'

# %%
import sys
import re
import numpy
import xml.etree.ElementTree as ET

# 0 for user input, 1 for file input
input_type = 0
stop_words_file = 'stop_words.txt'

unprocessed_questions = {}
processed_questions = {}
#isto é para saber das respostas repetidas
processed_answers = {}
same_question_id={}

questions_count = 0
answers = {}
test = []
stop_words = []


def setup():
    global unprocessed_questions
    global questions_count
    global answers
    global test
    global stop_words

    root = ET.parse('KB2.xml').getroot()

    for document in root.findall('documento'):
        for faq in document[1]:
            id = faq[2].get('id')
            answer = faq[2].text
            questions = []

            for question in faq[1]:
                questions_count += 1
                questions.append(question.text)

            unprocessed_questions[id] = questions
            answers[id] = answer

    with open(stop_words_file, 'r', encoding='utf-8') as swf:
        for line in swf:
            stop_words.append(line)

    if input_type == 1:
        with open(sys.argv[2], 'r', encoding='utf-8') as tests:
            for line in tests.readlines():
                test.append(line)


def preprocess():
    
    for id in unprocessed_questions:
        unprocessed = unprocessed_questions[id]
        processed = []
        processed_answers[id] = preprocess_sentence(answers[id])
        

        for question in unprocessed:
            processed.append(preprocess_sentence(question))

        processed_questions[id] = processed
    
    
    

def preprocess_sentence(sentence):
    sentence = re.sub(u'[ãâáàÃÂÁÀ]', 'a', sentence)
    sentence = re.sub(u'[êéèÊÉÈ]', 'e', sentence)
    sentence = re.sub(u'[îíìÎÍÌ]', 'i', sentence)
    sentence = re.sub(u'[õôóòÕÔÓÒ]', 'o', sentence)
    sentence = re.sub(u'[ûúùÛÚÙ]', 'u', sentence)
    sentence = re.sub(u'[çÇ]', 'c', sentence)

    sentence = sentence.lower()
    sentence = re.sub(u'[\?\.!:,;\(\)-_\\\'\"ºª/]', '', sentence)

    return sentence


def get_jaccard_sim(str1, str2): 
    a = set(str1.split()) 
    b = set(str2.split())
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

def compare_same_questions(processed_questions, processed_answers):
    samex=[]
    samei = []
    for x in processed_questions:
        for y in processed_questions[x]:
            for i in processed_questions:
                for j in processed_questions[i]:
                    if(x != i):
                        try:
                            jac= get_jaccard_sim(y,j)
                            if( jac> 0.9 and i not in samex and i not in samei ):
                                jac_answer = get_jaccard_sim(processed_answers[str(i)],processed_answers[str(x)])
                                if (jac_answer<0.8):
                                    #print(str(x)+' : '+str(i)+'  jac: '+str(jac)+' jac answer: '+ str(jac_answer))
                                    try:
                                        if (same_question_id[str(x)] < 1):
                                            same_question_id[str(x)] = 0
                                    except:
                                        same_question_id[str(x)] = 0
                                    try:
                                        if (same_question_id[str(i)] < 1):
                                            same_question_id[str(i)] = 0
                                    except:
                                        same_question_id[str(i)] = 0
                                if (jac_answer >= 0.8):
                                    try:
                                        same_question_id[str(x)] +=1
                                    except:
                                        same_question_id[str(x)] =1
                                    try:
                                        same_question_id[str(i)] +=1
                                    except:
                                        same_question_id[str(i)] =1
                                    #print(str(x)+' : '+str(i)+'  jac: '+str(jac)+' jac answer: '+ str(jac_answer)) 
                                samex.append(x)
                                samei.append(i)
                                #print(str(jac)+'\n'+j+'\n\n'+y+'\n\n\n')
                        except:
                            pass
                        
    #samex = set(samex)
    #print(samex)
    #samei = set(samei)
    #print(samei)

def weighted_score(processed_questions,processed_answers, user_input):
   
    max_question = 0
    max_answer = 0
    max_score = 0
    id_max_score = 0
    score_answer ={}
    score_question = {}
    score={}
    for id in processed_questions:
        processed = processed_questions[id]
        
        score_answer[id] = get_jaccard_sim(user_input,processed_answers[id])
        
        for question in processed:
            jac_question = get_jaccard_sim(user_input,question)
            if (max_question < jac_question):
                max_question = jac_question
        score_question[id] = max_question
        
    for i in processed_questions:
        try: 
            same_question_id[i]+=1
            same_question_id[i]-=1
        except:
            same_question_id[i]=1
    
    #print(same_question_id)
    #print(score_answer)
    #print(score_question)
    for ida in processed_questions:
        score[ida] = score_answer[ida]*0.3 +  score_question[ida]*0.4 + same_question_id[ida]* 0.3
        if(max_score < score[ida]):
            max_score = score[ida]
            id_max_score = ida
    print(str(max_score)+' for question id: '+str(id_max_score)+"\n")
    return (max_score,id_max_score)
    
    


def main():
    import time
    start_time = time.time()

    setup()
    preprocess()
    
    compare_same_questions(processed_questions,processed_answers)
    ##test if user string is null or ''
    ## process user input
    for id in processed_questions:
        processed = processed_questions[id]
        for question in processed:
            if(int(id)<=50 and len(question)>=1 and not question.isspace() ):
                print(id + ': ')
                print('user input: '+ question)
                weighted_score(processed_questions,processed_answers,question)
    #for i in range(50):
     #   i+=1
      #  weighted_score(processed_questions,processed_answers,processed_questions[i][1])
    
    #weighted_score(processed_questions,processed_answers, 'Pode ser emitido Cartão Eletrónico da Empresa ou de Pessoa Coletiva às entidades titulares de Cartão Definitivo de Identificação de Pessoa Coletiva ou entidade equiparada, emitido antes do dia 31/12/2008 ou inscritas anteriormente a essa data?')
   
    
    elapsed_time = time.time() - start_time
    print('Seconds to process:'+str(elapsed_time))

if __name__ == '__main__':
    main()
# Out:
# 1:
# user input: pode ser emitido cartao eletronico da empresa ou de pessoa coletiva as entidades titulares de cartao definitivo de identificacao de pessoa coletiva ou entidade equiparada emitido antes do dia  ou inscritas anteriormente a essa data
# 0.7789473684210526 for question id: 2
#
# 1:
# user input: e possivel emitir cartao eletronico da empresa ou de pessoa coletiva as entidades titulares de cartao definitivo de identificacao de pessoa coletiva ou entidade equiparada emitido antes do dia  ou inscritas anteriormente a essa data
# 0.7775862068965518 for question id: 2
#
# 1:
# user input: posso mandar fazer o cartao eletronico da empresa ou de pessoa coletiva as entidades titulares de cartao definitivo de identificacao de pessoa coletiva ou entidade equiparada emitido antes do dia  ou inscritas antes dessa data
# 0.7724137931034483 for question id: 2
#
# 1:
# user input: quero emitir o cartao eletronico da empresa ou de pessoa coletiva as entidades titulares de cartao definitivo de identificacao de pessoa coletiva ou entidade equiparada emitido antes do dia  ou inscritas antes dessa data e possivel
# 0.7775862068965518 for question id: 2
#
# 2:
# user input: como pedir o cartao provisorio de identificacao de pessoa coletiva
# 0.7545454545454546 for question id: 10
#
# 2:
# user input: como requerer o cartao provisorio de identificacao de pessoa coletiva
# 0.7545454545454546 for question id: 10
#
# 2:
# user input: o cartao provisorio de identificacao de pessoa coletiva e solicitado de que forma
# 0.7692307692307692 for question id: 170
#
# 2:
# user input: o cartao provisorio de identificacao de pessoa coletiva e pedido como
# 0.775 for question id: 170
#
# 3:
# user input: quando e emitido o cartao da empresacartao de pessoa coletiva
# 0.775 for question id: 170
#
# 3:
# user input: o cartao da empresacartao de pessoa coletiva e emitido quando
# 0.775 for question id: 170
#
# 3:
# user input: em que condicoes e o cartao da empresacartao de pessoa coletiva emitido
# 0.765625 for question id: 359
#
# 3:
# user input: cartao da empresacartao de pessoa coletiva e emitido em que ocasiao
# 0.7571428571428571 for question id: 580
#
# 4:
# user input: qual o custo do cartao da empresa e do cartao de pessoa coletiva
# 0.8 for question id: 170
#
# 4:
# user input: quanto custa o cartao da empresa e o cartao de pessoa coletiva
# 0.775 for question id: 170
#
# 4:
# user input: qual o preco do cartao da empresa e do cartao de pessoa coletiva
# 0.7692307692307692 for question id: 170
#
# 4:
# user input: o cartao da empresa e o cartao de pessoa coletiva custam quanto
# 0.775 for question id: 170
#
# 5:
# user input: onde posso pedir o cartao da empresa e o cartao de pessoa colectiva
# 0.7692307692307692 for question id: 170
#
# 5:
# user input: o cartao da empresa e o cartao de pessoa colectiva sao pedidos onde
# 0.7692307692307692 for question id: 170
#
# 5:
# user input: em que local posso pedir o cartao da empresa e o cartao de pessoa colectiva
# 0.76 for question id: 26
#
# 5:
# user input: em que zona posso mandar fazer o cartao da empresa e o cartao de pessoa colectiva
# 0.7583333333333333 for question id: 589
#
# 6:
# user input: para onde e enviado o cartao da empresa e o cartao de pessoa coletiva
# 0.7692307692307692 for question id: 170
#
# 6:
# user input: o cartao da empresa e o cartao de pessoa coletiva sao enviados para onde
# 0.7642857142857142 for question id: 170
#
# 6:
# user input: onde recebo o cartao da empresa e o cartao de pessoa coletiva
# 0.775 for question id: 170
#
# 6:
# user input: onde e entregue o cartao da empresa e o cartao de pessoa coletiva
# 0.775 for question id: 170
#
# 7:
# user input: o que e o cartao da empresa e o cartao de pessoa coletiva
# 0.7818181818181817 for question id: 170
#
# 7:
# user input: o que define o cartao da empresa e o cartao de pessoa coletiva
# 0.775 for question id: 170
#
# 7:
# user input: qual a definicao de cartao da empresa e de cartao de pessoa coletiva
# 0.7681818181818182 for question id: 10
#
# 7:
# user input: a que diz respeito o cartao da empresa e o cartao de pessoa coletiva
# 0.7692307692307692 for question id: 552
#
# 8:
# user input: qual a validade do cartao da empresa e do cartao de pessoa coletiva
# 0.7818181818181817 for question id: 10
#
# 8:
# user input: quando expira o cartao da empresa e do cartao de pessoa coletiva
# 0.7692307692307692 for question id: 170
#
# 8:
# user input: o cartao da empresa e do cartao de pessoa coletiva e valido ate quando
# 0.7642857142857142 for question id: 170
#
# 8:
# user input: qual a duracao do periodo de validade do cartao da empresa e do cartao de pessoa coletiva
# 0.775 for question id: 10
#
# 9:
# user input: como posso pedir o cartao eletronico da empresa ou de pessoa coletiva
# 0.7642857142857142 for question id: 180
#
# 9:
# user input: como requerer o cartao eletronico da empresa ou de pessoa coletiva
# 0.7666666666666666 for question id: 180
#
# 9:
# user input: o cartao eletronico da empresa ou de pessoa coletiva e solicitado de que forma
# 0.7666666666666666 for question id: 552
#
# 9:
# user input: o cartao eletronico da empresa ou de pessoa coletiva e pedido como
# 0.7666666666666666 for question id: 490
#
# 10:
# user input: o cartao de identificacao de pessoa coletiva ou entidade equiparada emitido pelo rnpc e de que sou titular continua a ser valido
# 0.8111111111111111 for question id: 10
#
# 10:
# user input: o cartao de identificacao de pessoa coletiva ou entidade equiparada emitido pelo rnpc e de que sou titular mantem a sua validade
# 0.8625 for question id: 10
#
# 10:
# user input: a validade do cartao de identificacao de pessoa coletiva ou entidade equiparada emitido pelo rnpc e de que sou titular mantemse
# 0.8320000000000001 for question id: 10
#
# 10:
# user input: o cartao de identificacao de pessoa coletiva ou entidade equiparada emitido pelo rnpc e de que sou titular permanece valido
# 0.8038461538461539 for question id: 10
#
# 11:
# user input: o cartao eletronico da empresa ou de pessoa coletiva pode ser cancelado
# 0.7714285714285714 for question id: 585
#
# 11:
# user input: e possivel cancelar o cartao eletronico da empresa ou de pessoa coletiva
# 0.7666666666666666 for question id: 490
#
# 11:
# user input: o cartao eletronico da empresa ou de pessoa coletiva pode ser anulado
# 0.7714285714285714 for question id: 585
#
# 11:
# user input: em que casos pode ser cancelado o cartao eletronico da empresa ou de pessoa coletiva
# 0.7705882352941176 for question id: 359
#
# 12:
# user input: o cartao da empresa e o cartao de pessoa coletiva podem ser cancelados
# 0.7692307692307692 for question id: 170
#
# 12:
# user input: e possivel cancelar o cartao da empresa e o cartao de pessoa coletiva
# 0.775 for question id: 170
#
# 12:
# user input: o cartao da empresa e o cartao de pessoa coletiva podem ser anulado
# 0.7692307692307692 for question id: 170
#
# 12:
# user input: em que casos podem ser cancelados o cartao da empresa e o cartao de pessoa coletiva
# 0.7685714285714286 for question id: 589
#
# 13:
# user input: o que e o cartao eletronico da empresa e de pessoa coletiva
# 0.775 for question id: 170
#
# 13:
# user input: o que define o cartao eletronico da empresa e de pessoa coletiva
# 0.7692307692307692 for question id: 170
#
# 13:
# user input: qual a definicao de cartao eletronico da empresa e de pessoa coletiva
# 0.76 for question id: 131
#
# 13:
# user input: a que diz respeito o cartao eletronico da empresa e de pessoa coletiva
# 0.7666666666666666 for question id: 552
#
# 14:
# user input: qual a diferenca entre o cartao da empresa e o cartao de pessoa coletiva
# 0.7681818181818182 for question id: 336
#
# 14:
# user input: o que distingue o cartao da empresa do cartao de pessoa coletiva
# 0.7580645161290323 for question id: 37
#
# 14:
# user input: em que difere o cartao da empresa do cartao de pessoa coletiva
# 0.767741935483871 for question id: 359
#
# 14:
# user input: o cartao da empresa e o cartao de pessoa coletiva sao distinguidos como
# 0.7692307692307692 for question id: 170
#
# 15:
# user input: que tipo de sociedades podem ser constituidas atraves do servico de criacao de empresa online
# 0.7705882352941176 for question id: 113
#
# 15:
# user input: quais sao os tipos de sociedades podem ser constituidas atraves do servico de criacao de empresa online
# 0.763157894736842 for question id: 113
#
# 15:
# user input: que tipo de sociedades posso constituir atraves do servico de criacao de empresa online
# 0.7562500000000001 for question id: 582
#
# 15:
# user input: que tipo de sociedades se conseguem constituir atraves do servico de criacao de empresa online
# 0.7529411764705882 for question id: 582
#
# 16:
# user input: ha sociedades que nao podem ser constituidas atraves do servico de criacao de empresa online
# 0.7666666666666666 for question id: 113
#
# 16:
# user input: ha alguma sociedade que nao possa ser constituida atraves do servico de criacao de empresa online
# 0.7517241379310344 for question id: 21
#
# 16:
# user input: existem sociedades que nao podem ser constituidas atraves do servico de criacao de empresa online
# 0.7666666666666666 for question id: 113
#
# 16:
# user input: existe alguma sociedade que nao possa ser constituida atraves do servico de criacao de empresa online
# 0.7517241379310344 for question id: 21
#
# 17:
# user input: a partir de onde poder ser acedido o servico de criacao de empresa online
# 0.7782608695652173 for question id: 590
#
# 17:
# user input: a partir de onde posso aceder ao servico de criacao de empresa online
# 0.75 for question id: 590
#
# 17:
# user input: a partir de que sitio pode ser acedido o servico de criacao de empresa online
# 0.775 for question id: 47
#
# 17:
# user input: a partir de onde se pode aceder ao servico de criacao de empresa online
# 0.748 for question id: 590
#
# 18:
# user input: quem pode constituir uma empresa atraves do servico de criacao de empresa online
# 0.76 for question id: 49
#
# 18:
# user input: quem e autorizado a constituir uma empresa atraves do servico de criacao de empresa online
# 0.7710526315789474 for question id: 28
#
# 18:
# user input: quem e capaz de constituir uma empresa atraves do servico de criacao de empresa online
# 0.772 for question id: 49
#
# 18:
# user input: quem pode constituir uma empresa utilizando o servico de criacao de empresa online
# 0.7652173913043478 for question id: 47
#
# 19:
# user input: como se escolhe a firma
# 0.7333333333333334 for question id: 262
#
# 19:
# user input: como e que se escolhe a firma
# 0.7473684210526316 for question id: 262
#
# 19:
# user input: como escolho a firma
# 0.7352941176470589 for question id: 262
#
# 19:
# user input: como e escolhida a firma
# 0.7529411764705882 for question id: 262
#
# 20:
# user input: para a constituicao de uma empresa atraves do servico de criacao de empresa online e necessaria
# a presenca de todos os socios
# 0.7825 for question id: 28
#
# 20:
# user input: e necessaria a presenca de todos os socios para a constituicao de uma empresa atraves do servico de criacao de empresa online
# 0.7825 for question id: 28
#
# 20:
# user input: para a constituicao de uma empresa atraves do servico de criacao de empresa online e precisa
# a presenca de todos os socios
# 0.7825 for question id: 28
#
# 20:
# user input: para a constituicao de uma empresa atraves do servico de criacao de empresa online todos os socios tem de estar presentes
# 0.7731707317073171 for question id: 28
#
# 21:
# user input: posso reservar previamente de entre as firmas constantes da lista de nomes fantasia o nome que
# pretendo para a minha empresa
# 0.765625 for question id: 21
#
# 21:
# user input: posso reservar antecipadamente de entre as firmas constantes da lista de nomes fantasia o nome que
# pretendo para a minha empresa
# 0.765625 for question id: 21
#
# 21:
# user input: e possivel reservar previamente de entre as firmas constantes da lista de nomes fantasia o nome que
# pretendo para a minha empresa
# 0.7685714285714286 for question id: 445
#
# 21:
# user input: e possivel reservar antecipadamente de entre as firmas constantes da lista de nomes fantasia o nome que
# pretendo para a minha empresa
# 0.7685714285714286 for question id: 445
#
# 22:
# user input: qual o custo de constituicao de uma empresa online ou de uma empresa online com marca
# associada
# 0.7642857142857142 for question id: 170
#
# 22:
# user input: quanto custa de constituicao de uma empresa online ou uma empresa online com marca
# associada
# 0.746875 for question id: 66
#
# 22:
# user input: qual o custo de constituir uma empresa online ou uma empresa online com marca
# associada
# 0.7642857142857142 for question id: 170
#
# 22:
# user input: qual e o custo para constituir uma empresa online ou uma empresa online com marca
# associada
# 0.7636363636363637 for question id: 572
#
# 23:
# user input: quais sao os prazos de pagamento associados ao servico de criacao de empresa online
# 0.745 for question id: 538
#
# 23:
# user input: quais sao os prazos de pagamento relativos ao servico de criacao de empresa online
# 0.745 for question id: 538
#
# 23:
# user input: qual e o prazo de pagamento associado ao servico de criacao de empresa online
# 0.7833333333333333 for question id: 68
#
# 23:
# user input: qual e o prazo para pagar a criacao de uma empresa online
# 0.775 for question id: 230
#
# 24:
# user input: caso existam inconformidades no processo o que sucede
# 0.7413793103448276 for question id: 179
#
# 24:
# user input: havendo inconformidades no processo o que acontece
# 0.74 for question id: 86
#
# 24:
# user input: na eventualidade da existencia de inconformidades no processo qual e o procedimento
# 0.7642857142857142 for question id: 170
#
# 24:
# user input: o que sucede na ocorrencia de inconformidades no processo
# 0.7517241379310344 for question id: 108
#
# 25:
# user input: quando deverei efectuar o deposito do capital social da empresa online
# 0.8 for question id: 26
#
# 25:
# user input: em que altura deve o deposito do capital social da empresa online ser feito
# 0.8043478260869565 for question id: 26
#
# 25:
# user input: o deposito do capital social da empresa online deve ser feito quando
# 0.7954545454545454 for question id: 26
#
# 25:
# user input: quando devem os socios fazer o deposito do capital social da empresa online
# 0.791304347826087 for question id: 26
#
# 26:
# user input:  quando e possivel o levantamento do capital social da empresa online
# 0.8666666666666667 for question id: 26
#
# 26:
# user input:  em que altura posso fazer o levantamento do capital social da empresa social
# 0.8142857142857143 for question id: 26
#
# 26:
# user input:  quando fica o capital social da empresa online disponivel para levantamento
# 0.8 for question id: 26
#
# 26:
# user input:  a partir de que momento se torna possivel o levantamento do capital social da empresa online
# 0.8500000000000001 for question id: 26
#
# 27:
# user input:  a escolha de uma firma preaprovada pode limitar de alguma forma o objecto social que pretendo para a minha empresa
# 0.76 for question id: 340
#
# 27:
# user input:  pode o objecto social que quero para a minha empresa ficar de alguma forma limitado pela escolha duma firma preaprovada
# 0.7555555555555555 for question id: 340
#
# 27:
# user input:  e posssivel que a escolha duma firma preaprovada limite o objecto social pretendido para a minha empresa
# 0.75 for question id: 340
#
# 27:
# user input:  pode a escolha de uma firma preaprovada de alguma forma limitar o objecto social que quero para a minha empresa
# 0.76 for question id: 340
#
# 28:
# user input:  disponho de um certificado de admissibilidade de firma valido posso utilizalo para constituir a minha empresa atraves do servico de criacao de empresa online
# 0.7878048780487805 for question id: 28
#
# 28:
# user input:  tenho um certificado de admissibilidade de firma valido pode este ser utilizado para constituir a minha empresa atraves do servico de criacao de empresa online
# 0.7931034482758621 for question id: 47
#
# 28:
# user input:  possuo um certificado de admissibilidade de firma valido e possivel utilizalo a fim de constituir a minha empresa atraves do servico de criacao de empresa online
# 0.7857142857142857 for question id: 28
#
# 28:
# user input:  sendo eu possuidor dum certificado de admissibilidade de firma valido posso recorrendo ao servico de criacao de empresa online utilizalo para constituir a minha empresa
# 0.7666666666666666 for question id: 28
#
# 29:
# user input:  como poderei obter o certificado de admissibilidade
# 0.76 for question id: 150
#
# 30:
# user input:  como aceder ao forum de validacao do pacto social
# 0.7428571428571429 for question id: 582
#
# 31:
# user input:  a inscricao da sociedade nas financas na seguranca social e outros servicos publicos sao efectuados no momento da constituicao
# 0.7724137931034483 for question id: 121
#
# 31:
# user input:  e no momento da constituicao que a inscricao da sociedade nas financas na seguranca social e noutros servicos publicos deve ser feita
# 0.767741935483871 for question id: 121
#
# 31:
# user input:  aquando a constituicao deve ser feita a inscricao da sociedade nas financas na seguranca social e noutros servicos publicos
# 0.76 for question id: 121
#
# 31:
# user input:  deve a inscricao da sociedade nas financas na seguranca social e noutros servicos publicos ser feita no momento da constituicao
# 0.77 for question id: 121
#
# 32:
# user input:  sera possivel utilizar o processo de constituicao da empresa online quando os socios sao pessoas colectivas e se forem pessoas colectivas estrangeiras existe algum formalismo previo
# 0.7529411764705882 for question id: 98
#
# 32:
# user input:  sendo os socios pessoas colectivas e possivel utilizar o processo de constituicao da empresa online e caso estes sejam pessoas colectivas estrangeiras ha algum formalismo extra
# 0.754 for question id: 98
#
# 32:
# user input:  o processo de constituicao da empresa online esta disponivel quando os socios sao pessoas colectivas ha algumas regras adicionais caso estes sejam pessoas colectivas
# 0.75 for question id: 120
#
# 32:
# user input:  caso os socios sejam pessoas colectivas sera possivel utilizar o processo de constituicao da empresa online e sendo estes pessoas colectivas estrangeiras o processo alterase
# 0.758695652173913 for question id: 120
#
# 33:
# user input:  sera possivel a cidadaos estrangeiros a constituicao de uma empresa online nestes casos existe algum formalismo previo que deva ser respeitado
# 0.7533333333333334 for question id: 33
#
# 33:
# user input:  cidadaos estrangeiros podem constituir uma empresa online se assim for deve ser respeitado algum formalismo
# 0.74 for question id: 49
#
# 33:
# user input:  a constituicao de uma empresa online e possivel para cidadao estrangeiros sendo assim que formalismo previo tem de ser respeitado
# 0.7724137931034483 for question id: 80
#
# 33:
# user input:  e possivel a constituicao de uma empresa online para cidadaos estrangeiros qual o formalismo previo a ser respeitado
# 0.7642857142857142 for question id: 80
#
# 34:
# user input:  e possivel indicar um tecnico oficial de contas toc no momento da constituicao da empresa online
# 0.775 for question id: 131
#
# 34:
# user input:  um tecnico oficial de contas toc pode ser indicado no momento da constituicao da empresa online
# 0.775 for question id: 131
#
# 34:
# user input:  no momento da constituicao da empresa online pode ser indicado um tecnico oficial de contas toc
# 0.775 for question id: 131
#
# 34:
# user input:  quando se da a constituicao da empresa online e possivel que seja indicado um tecnico oficial de contas toc
# 0.775 for question id: 445
#
# 35:
# user input:  qual e o website onde irao ser feitas as publicacoes
# 0.7562500000000001 for question id: 106
#
# 35:
# user input:  as publicacoes serao feitas em qual website
# 0.7352941176470589 for question id: 35
#
# 35:
# user input:  qual e o endereco online onde apareceram as publicacoes
# 0.7571428571428571 for question id: 132
#
# 35:
# user input:  onde e que posso aceder de forma online as publicacoes
# 0.7521739130434782 for question id: 80
#
# 36:
# user input:  qual o prazo que a conservatoria tem para efectuar o registo
# 0.7666666666666666 for question id: 340
#
# 36:
# user input:  o registo sera efetuado pela conservatoria ate quando
# 0.73 for question id: 85
#
# 36:
# user input:  em que data e que e dado o registo pela conservatoria
# 0.75 for question id: 170
#
# 36:
# user input:  quando e que a conservatoria ira realizar o registo
# 0.76 for question id: 491
#
# 37:
# user input:  como recebo o cartao da empresa
# 0.7413793103448276 for question id: 37
#
# 37:
# user input:  como e que sera remetido o cartao da empresa
# 0.75 for question id: 170
#
# 37:
# user input:  quanto ao cartao da empresa como e que o recebo
# 0.7580645161290323 for question id: 37
#
# 37:
# user input:  como e que terei acesso ao cartao da empresa
# 0.76 for question id: 37
#
# 38:
# user input:  quais as vantagens de aderir a um centro de arbitragem
# 0.76 for question id: 139
#
# 38:
# user input:  o que e que tenho a ganhar ao aderir a um centro de arbitragem
# 0.7875000000000001 for question id: 219
#
# 38:
# user input:  qual e a utilidade da adesao a um centro de arbitragem
# 0.78 for question id: 512
#
# 38:
# user input:  relativamente a aderencia de um centro de arbitragem quais as suas vantagens
# 0.7529411764705882 for question id: 512
#
# 39:
# user input:  existe alguma especificidade quanto a aos caes escolhidos
# 0.7230769230769232 for question id: 112
#
# 39:
# user input:  quanto aos caes escolhidos existe alguma especificidade
# 0.712 for question id: 53
#
# 39:
# user input:  existe alguma excecao no que toca aos caes selecionados
# 0.7290322580645161 for question id: 492
#
# 39:
# user input:  relativamente aos caes selecionados existe alguma excecao
# 0.712 for question id: 53
#
# 40:
# user input:  o que e um certificado digital
# 0.7833333333333333 for question id: 47
#
# 40:
# user input:  em que consiste um certificado digital
# 0.763157894736842 for question id: 47
#
# 40:
# user input:  que informacoes existem acerca do certificado digital
# 0.7428571428571429 for question id: 47
#
# 40:
# user input:  que mais posso saber do certificado digital
# 0.7428571428571429 for question id: 47
#
# 41:
# user input: sou advogado e já tenho um certificado digital que integra a minha cédula profissional posso utilizar este certificado para me autenticar e utilizar o serviço de criação de empresa
# 0.7804878048780488 for question id: 41
#
# 41:
# user input: sendo advogado posso utilizar o certificado digital que integra a minha cedula profissional para me autenticar e utilizar o servico de criacao de empresa
# 0.7562500000000001 for question id: 47
#
# 41:
# user input: e possivel utilizar o certificado digital que integra a minha cedula profissional de advogado para me autenticar e utilizar o servico de criacao de empresas
# 0.77 for question id: 47
#
# 41:
# user input: posso utilizar o certificado digital que integra a minha cedula proffisional de advogado para me autenticar e utilizar o servico de criacao de empresas
# 0.77 for question id: 47
#
# 42:
# user input: que tipo de certificado é que pode ser utilizado no processo de criação de empresa
# 0.7782608695652173 for question id: 47
#
# 42:
# user input: no processo de criacao de empresa que tipo de certificado e que pode ser utilizado
# 0.7782608695652173 for question id: 47
#
# 42:
# user input: quais os certificados que podem ser utilizados no processo de criacao de empresa
# 0.7625 for question id: 590
#
# 42:
# user input: que certificados podem ser usados no processo de criacao de empresa
# 0.7681818181818182 for question id: 590
#
# 43:
# user input: o que é um certificado digital qualificado
# 0.7789473684210526 for question id: 47
#
# 43:
# user input: quais as caracteristicas de um certificado digital qualificado
# 0.7571428571428571 for question id: 47
#
# 43:
# user input: qual e a definicao de um certificado digital qualificado
# 0.7857142857142857 for question id: 512
#
# 43:
# user input: o que caracteriza um certificado digital qualificado
# 0.7789473684210526 for question id: 47
#
# 44:
# user input: onde posso adquirir um certificado digital qualificado
# 0.7428571428571429 for question id: 47
#
# 44:
# user input: em que sitios posso adquirir um certificado digital qualificado
# 0.7545454545454546 for question id: 47
#
# 44:
# user input: em que locais posso adquirir um certificado digital qualificado
# 0.7545454545454546 for question id: 47
#
# 44:
# user input: como posso adquirir um certificado digital qualificado
# 0.7428571428571429 for question id: 47
#
# 45:
# user input: o meu pacto social digitalizado não se encontra muito legível que devo fazer
# 0.7567567567567568 for question id: 46
#
# 45:
# user input: o que devo fazer no caso de o meu pacto social digitalizado nao se encontrar muito legivel
# 0.7535714285714286 for question id: 150
#
# 45:
# user input: no caso de o meu pacto social digitalizado nao se encontrar muito legivel o que devo fazer
# 0.7535714285714286 for question id: 150
#
# 45:
# user input: o meu pacto social digitalizado encontrase pouco legivel que devo fazer
# 0.7315789473684211 for question id: 86
#
# 46:
# user input: a assinatura não se encontra legível que posso fazer
# 0.7428571428571429 for question id: 46
#
# 46:
# user input: o que posso fazer no caso de a assinatura nao se encontrar muito legivel
# 0.7625 for question id: 491
#
# 46:
# user input: no caso de a assinatura nao se encontrar legivel o que posso fazer
# 0.7652173913043478 for question id: 491
#
# 46:
# user input: a assinatura encontrase pouco legivel que posso fazer
# 0.7333333333333334 for question id: 340
#
# 47:
# user input: o cartão de cidadão pode ser utilizado no processo de criação da empresa online
# 0.8090909090909091 for question id: 47
#
# 47:
# user input: no processo de criacao da empresa online pode ser utilizado o cartao de cidadao
# 0.7857142857142857 for question id: 585
#
# 47:
# user input: ao criar a empresa online pode ser utilizado o cartao de cidadão
# 0.7954545454545454 for question id: 47
#
# 47:
# user input: posso utilizar o cartao de cidadao na criacao da empresa online
# 0.76 for question id: 136
#
# 48:
# user input:  como posso enviar o pacto social e o anexo de reconhecimento para o portal da empresa
# 0.7562500000000001 for question id: 170
#
# 48:
# user input:  de que formas posso enviar o pacto social e o anexo de reconhecimento para o portal da empresa
# 0.7580645161290323 for question id: 445
#
# 48:
# user input:  como devo proceder para enviar o pacto social e o anexo de reconhecimento para o portal da empresa
# 0.7529411764705882 for question id: 170
#
# 48:
# user input:  o que fazer para enviar o pacto social e o anexo de reconhecimento para o portal da empresa
# 0.76 for question id: 445
#
# 49:
# user input: um cidadão estrangeiro pode constituir uma empresa através do serviço de criação de empresa online
# 0.7555555555555555 for question id: 49
#
# 49:
# user input: e possivel um cidadão estrangeiro constituir uma empresa através do serviço de criação de empresa online
# 0.7666666666666666 for question id: 49
#
# 49:
# user input: pode um cidadao estrangeiro constituir uma empresa atraves do servico de criacao de empresa online
# 0.765625 for question id: 66
#
# 49:
# user input: o servico de criacao de empresa online permite que um cidadao estrangeiro constitua uma empresa
# 0.76 for question id: 590
#
# 50:
# user input: o que e uma certidao permanente
# 0.79375 for question id: 65
#
# 50:
# user input: qual a definicao de certidao permanente
# 0.8 for question id: 59
#
# 50:
# user input: o que define uma certidao permanente
# 0.79375 for question id: 65
#
# 50:
# user input: em que consiste uma certidao permanente
# 0.79375 for question id: 65
#
# 51:
# user input: como posso ter acesso a uma certidao permanente
# 0.79 for question id: 92
#
# 51:
# user input: como aceder a uma certidao permanente
# 0.7692307692307692 for question id: 59
#
# 51:
# user input: como e possivel aceder a uma certidao permanente
# 0.76 for question id: 59
#
# 51:
# user input: de que maneira posso aceder a uma certidao permanente
# 0.78 for question id: 59
#
# 52:
# user input: onde posso pedir uma certidao permanente
# 0.75 for question id: 65
#
# 52:
# user input: em que local posso pedir uma certidao permanente
# 0.7833333333333333 for question id: 65
#
# 52:
# user input: onde pedir certidao permanente
# 0.75 for question id: 59
#
# 52:
# user input: onde me posso dirigir para pedir uma certidao permanente
# 0.75 for question id: 53
#
# 53:
# user input: quem pode pedir uma certidao permanente online
# 0.7545454545454546 for question id: 53
#
# 53:
# user input: posso pedir uma certidao permanente online
# 0.7571428571428571 for question id: 53
#
# 53:
# user input: quem e elegivel para o pedido de uma certidao permanente online
# 0.8090909090909091 for question id: 53
#
# 53:
# user input: qualquer pessoa pode pedir uma certidao permanente online
# 0.7857142857142857 for question id: 53
#
# 53:
# user input: condicoes para pedir uma certidao permanente online
# 0.7714285714285714 for question id: 53
#
# 54:
# user input: quais as vantagens de subscrever uma certidao permanente
# 0.76 for question id: 59
#
# 54:
# user input: quais as vantagens de pedir uma certidao permanente
# 0.76 for question id: 59
#
# 54:
# user input: o que ganho em pedir uma certidao permanente
# 0.8058823529411765 for question id: 65
#
# 54:
# user input: beneficios de pedir uma certidao permanente
# 0.7692307692307692 for question id: 59
#
# 54:
# user input: porque pedir uma certidao permanente
# 0.7529411764705882 for question id: 65
#
# 54:
# user input: razoes para pedir uma certidao permanente
# 0.75 for question id: 65
#
# 54:
# user input: o que da o pedido de uma certidao permanente
# 0.8058823529411765 for question id: 65
#
# 54:
# user input: porque requerer uma certidao permanente
# 0.7529411764705882 for question id: 65
#
# 55:
# user input: qual a informacao que consta de uma certidao permanente
# 0.78 for question id: 59
#
# 55:
# user input: o que consta numa certidao permanente
# 0.7705882352941176 for question id: 65
#
# 55:
# user input: que informacao posso encontrar numa certidao permanente
# 0.7473684210526316 for question id: 65
#
# 55:
# user input: o que tem uma certidao permanente
# 0.8200000000000001 for question id: 65
#
# 55:
# user input: qual o conteudo de uma certidao permanente
# 0.7923076923076924 for question id: 59
#
# 56:
# user input: posso imprimir a certidao permanente
# 0.775 for question id: 59
#
# 56:
# user input: devo imprimir a certidao permanente
# 0.775 for question id: 59
#
# 56:
# user input: preciso de imprimir a certidao permanente
# 0.8 for question id: 59
#
# 56:
# user input: e possivel imprimir a certidao permanente
# 0.7692307692307692 for question id: 59
#
# 56:
# user input: e obrigatorio imprimir a certidao permanente
# 0.7692307692307692 for question id: 59
#
# 57:
# user input: a partir de e ate quando posso renovar a certidao permanente
# 0.7818181818181817 for question id: 92
#
# 57:
# user input: quais os prazos para a renovacao da certidao permanente
# 0.7562500000000001 for question id: 59
#
# 57:
# user input: qual a validade da certidao permanente
# 0.7692307692307692 for question id: 59
#
# 57:
# user input: quando preciso de renovar a certidao permanente
# 0.7923076923076924 for question id: 59
#
# 58:
# user input: e se nao me lembrar da data do fim de validade da certidao
# 0.77 for question id: 58
#
# 58:
# user input: o que acontece se me esquecer de renovar a certidao permanente
# 0.79375 for question id: 59
#
# 58:
# user input: e se me esquecer da data do fim de validade da certidao
# 0.7724137931034483 for question id: 58
#
# 58:
# user input: sou notificado relativamente ao prazo de validade da certidao
# 0.7517241379310344 for question id: 58
#
# 59:
# user input: ao renovar a minha certidao vou ter um novo codigo de acesso
# 0.7882352941176471 for question id: 59
#
# 59:
# user input: quando renovar a minha certidao recebo outro codigo de acesso
# 0.8 for question id: 59
#
# 59:
# user input: ao renovar a minha certidao recebo outro codigo de acesso
# 0.8 for question id: 59
#
# 59:
# user input: o codigo e permanente no caso de renovacao da certidao
# 0.8 for question id: 59
#
# 59:
# user input: o codigo e permanente ao renovar a certidao
# 0.8153846153846154 for question id: 59
#
# 59:
# user input: renovar a minha certidao resulta em mudanca do codigo de acesso
# 0.79375 for question id: 59
#
# 60:
# user input: o que e a extratacao de uma entidade
# 0.79 for question id: 170
#
# 60:
# user input: em que consiste uma extratacao de uma entidade
# 0.7681818181818182 for question id: 60
#
# 60:
# user input: o que significa extratacao de uma entidade
# 0.76 for question id: 170
#
# 60:
# user input: qual a definicao de extratacao de uma entidade
# 0.7681818181818182 for question id: 60
#
# 61:
# user input: quanto tempo podera levar a extractar uma entidade
# 0.7315789473684211 for question id: 230
#
# 61:
# user input: quanto tempo demora a extractar uma entidade
# 0.7333333333333334 for question id: 230
#
# 61:
# user input: tempo que a extratacao de uma entidade demora
# 0.7529411764705882 for question id: 340
#
# 61:
# user input: qual a duracao de tempo associada a uma extratacao de uma entidade
# 0.76 for question id: 336
#
# 61:
# user input: qual o periodo de tempo associada a uma extratacao de uma entidade
# 0.775 for question id: 336
#
# 61:
# user input: qual a duracao de uma extratacao de uma entidade
# 0.7529411764705882 for question id: 202
#
# 62:
# user input: qual o custo de uma certidao permanente e quais as modalidades de pagamento
# 0.7923076923076924 for question id: 170
#
# 62:
# user input: quanto custa uma certidao e como posso pagala
# 0.7391304347826086 for question id: 92
#
# 62:
# user input: quanto custa uma e como posso pagar uma certidao permanente
# 0.7521739130434782 for question id: 92
#
# 62:
# user input: qual o valor de uma certidao permanente
# 0.7882352941176471 for question id: 65
#
# 62:
# user input: qual o preco de uma certidao permanente
# 0.7666666666666666 for question id: 65
#
# 62:
# user input: como posso pagar uma certidao permanente
# 0.75 for question id: 65
#
# 62:
# user input: metodos de pagamento de certidao permanente
# 0.7461538461538462 for question id: 490
#
# 63:
# user input: em que consiste o registo comercial bilingue
# 0.7562500000000001 for question id: 64
#
# 63:
# user input: o que e o registo comercial bilingue
# 0.7666666666666666 for question id: 170
#
# 63:
# user input: o que significa registo comercial bilingue
# 0.746875 for question id: 64
#
# 63:
# user input: qual a definicao de registo comercial bilingue
# 0.7705882352941176 for question id: 133
#
# 64:
# user input: quais as vantagens do registo comercial bilingue
# 0.75 for question id: 133
#
# 64:
# user input: o que ganho com o registo comercial bilingue
# 0.7454545454545455 for question id: 64
#
# 64:
# user input: quais os beneficios do registo comercial bilingue
# 0.75 for question id: 133
#
# 64:
# user input: porque fazer o registo comercial bilingue
# 0.7363636363636363 for question id: 64
#
# 64:
# user input: razoes para fazer o registo comercial bilingue
# 0.7352941176470589 for question id: 64
#
# 65:
# user input: qual o valor juridico da certidao permanente de registo na versao inglesa
# 0.7857142857142857 for question id: 65
#
# 65:
# user input: na versao inglesa qual o valor legal da certidao permanente
# 0.775 for question id: 65
#
# 65:
# user input: segundo a lei qual o estatuto juridico de uma certidao permanente inglesa
# 0.7857142857142857 for question id: 65
#
# 65:
# user input: qual o alcance juridico da certidao permanente de registo na versao inglesa
# 0.7771428571428571 for question id: 67
#
# 66:
# user input: como posso aceder ao registo comercial em ingles
# 0.74 for question id: 66
#
# 66:
# user input: e possivel ler o registo comercial em ingles
# 0.7545454545454546 for question id: 121
#
# 66:
# user input: onde encontrar o registo comercial na versao inglesa
# 0.7428571428571429 for question id: 67
#
# 66:
# user input: consigo ver o registo comercial em ingles
# 0.7413793103448276 for question id: 66
#
# 67:
# user input: qual o custo de uma certidao permanente de registo em versao inglesa e quais as modalidades de pagamento
# 0.8 for question id: 67
#
# 67:
# user input: quanto custa uma certidao permanente de registo na versao inglesa
# 0.76 for question id: 67
#
# 67:
# user input: como posso pagar uma certidao permanente de registo em ingles
# 0.7652173913043478 for question id: 92
#
# 67:
# user input: qual o valor e de que maneira e possivel pagar uma certidao permanente na versao inglesa
# 0.7615384615384615 for question id: 67
#
# 68:
# user input: qual o prazo de disponibilizacao da certidao permanente na versao inglesa
# 0.7571428571428571 for question id: 580
#
# 68:
# user input: quanto tempo demora uma certidao permanente na versao inglesa
# 0.7285714285714286 for question id: 580
#
# 68:
# user input: a versao inglesa da certidao permanente tem que disponibilidade
# 0.745 for question id: 580
#
# 68:
# user input: a certidao na versao inglesa tem prazo para ser disponibilizada
# 0.76 for question id: 580
#
# 69:
# user input: que actos do registo comercial posso pedir pela internet
# 0.745 for question id: 133
#
# 69:
# user input: quais os actos do registo comercial que posso pedir pela internet
# 0.7428571428571429 for question id: 141
#
# 69:
# user input: e possivel pedir actos do registo comercial pela internet
# 0.7473684210526316 for question id: 202
#
# 69:
# user input: quais os actos do registo comercial estao disponiveis na internet
# 0.763157894736842 for question id: 141
#
# 70:
# user input: quem pode realizar um pedido de registo por transcricao
# 0.7545454545454546 for question id: 76
#
# 70:
# user input: quais as pessoas que podem realizar um pedido de registo por transcricao
# 0.75 for question id: 83
#
# 70:
# user input: todos podem fazer um pedido de registo por transcricao
# 0.7545454545454546 for question id: 76
#
# 70:
# user input: e possivel realizar um pedido de registo por transcricao
# 0.7666666666666666 for question id: 202
#
# 71:
# user input: para que tipo de sociedades posso fazer um registo por transcricao
# 0.7562500000000001 for question id: 71
#
# 71:
# user input: quais os tipos de sociedades para os quais posso fazer um registos por transcricao
# 0.7529411764705882 for question id: 71
#
# 71:
# user input: os registos por transcricao sao feitos para que tipo de sociedades
# 0.76 for question id: 84
#
# 71:
# user input: quais as tipologias das sociedades para as quais posso fazer um registo por transcricao
# 0.7529411764705882 for question id: 71
#
# 72:
# user input: que pedidos de registo por transcricao posso efectuar
# 0.75 for question id: 202
#
# 72:
# user input: quais os pedidos de registo por transcricao que posso fazer
# 0.745 for question id: 202
#
# 72:
# user input: que pedidos de registo por transcricao sao possiveis
# 0.75 for question id: 202
#
# 72:
# user input: quais os registos por transcricao posso pedir
# 0.7285714285714286 for question id: 81
#
# 73:
# user input: que documentos sao necessarios submeter para efectivar um registo por transcricao
# 0.75 for question id: 86
#
# 73:
# user input: como tornar efectivo um registo por transcricao
# 0.7333333333333334 for question id: 202
#
# 73:
# user input: quais os documentos necessarios para um registo por transcricao
# 0.7375 for question id: 104
#
# 73:
# user input: o que e preciso submeter para efectivar um registo por transcricao
# 0.76 for question id: 84
#
# 74:
# user input: depois de efectuado o registo vou ter acesso a algum comprovativo
# 0.7625 for question id: 92
#
# 74:
# user input: tendo efetuado o registo recebo algum comprovativo
# 0.728125 for question id: 74
#
# 74:
# user input: que comprovativo tenho do registo efetuado
# 0.7352941176470589 for question id: 202
#
# 74:
# user input: recebo um comprovativo ao efetuar o registo
# 0.7428571428571429 for question id: 76
#
# 75:
# user input: qual o custo associado a um pedido de registo por transcricao
# 0.8 for question id: 76
#
# 75:
# user input: quanto custa um pedido de registo por transcricao
# 0.7571428571428571 for question id: 76
#
# 75:
# user input: um pedido de registo por transcricao tem que custo associado
# 0.7681818181818182 for question id: 76
#
# 75:
# user input: qual o preco de um pedido de registo por transcricao
# 0.7714285714285714 for question id: 76
#
# 76:
# user input: posso requerer o caracter de urgencia em qualquer registo por transcricao
# 0.75 for question id: 76
#
# 76:
# user input: e possivel requerer o caracter de urgencia em qualquer registo por transcricao
# 0.7642857142857142 for question id: 170
#
# 76:
# user input: quais os registos por transcricao em que posso requerer o caracter de urgencia
# 0.75 for question id: 589
#
# 76:
# user input: o requerimento do caracter de urgencia esta associado a quaisquer registo por transcricao
# 0.7714285714285714 for question id: 202
#
# 77:
# user input: quanto tempo demora a realizacao de um registo por transcricao
# 0.763157894736842 for question id: 202
#
# 77:
# user input: qual o periodo de tempo da realizacao de um registo por transcricao
# 0.76 for question id: 230
#
# 77:
# user input: qual a duracao da realizacao de um registo por transcricao
# 0.7833333333333333 for question id: 202
#
# 77:
# user input: a realizacao de um registo por transcricao demora quanto tempo
# 0.763157894736842 for question id: 202
#
# 78:
# user input: como sei se e necessario efetuar alteracoes ao pedido de registo
# 0.7555555555555555 for question id: 190
#
# 78:
# user input: sou avisado se for preciso efectuar alteracoes ao pedido de registo
# 0.7681818181818182 for question id: 105
#
# 78:
# user input: sou notificado se for preciso efectuar alteracoes ao pedido de registo
# 0.7681818181818182 for question id: 105
#
# 78:
# user input: serao precisas alteracoes ao pedido de registo
# 0.75 for question id: 190
#
# 78:
# user input: o que acontece se for preciso fazer alteracoes ao pedido de registo
# 0.7652173913043478 for question id: 105
#
# 79:
# user input: depois de confirmado qualquer registo por transcricao vou ter acesso a algum comprovativo
# 0.7576923076923077 for question id: 92
#
# 79:
# user input: depois de fazer um registo por transcricao recebo algum comprovativo
# 0.745 for question id: 202
#
# 79:
# user input: apos fazer um registo por transcricao tenho acesso a algum comprovativo
# 0.7428571428571429 for question id: 202
#
# 79:
# user input: eme dado algum comprovativo por fazer um registo por transcricao
# 0.73 for question id: 202
#
# 79:
# user input: fico com algum comprovativo apos fazer um registo por transcricao
# 0.73 for question id: 334
#
# 80:
# user input: se o registo ficar provisorio posso pedir a sua conversao pela internet
# 0.7375 for question id: 336
#
# 80:
# user input: caso o registo fique provisorio posso pedir a sua conversao pela internet
# 0.7375 for question id: 336
#
# 80:
# user input: e possivel pedir uma conversao pela internet do registo caso este fique provisorio
# 0.7391304347826086 for question id: 202
#
# 80:
# user input: consigo pedir uma conversao pela internet do registo caso este fique provisorio
# 0.7279069767441861 for question id: 144
#
# 81:
# user input: que tipo de pedidos de registo por deposito posso efectuar
# 0.7473684210526316 for question id: 202
#
# 81:
# user input: quais os pedidos de registo por deposito que posso efetuar
# 0.745 for question id: 202
#
# 81:
# user input: que pedidos de registo por deposito sao possiveis de efetuar
# 0.7473684210526316 for question id: 202
#
# 81:
# user input: quais os tipos de pedidos de registo por deposito que sao possiveis
# 0.75 for question id: 586
#
# 82:
# user input: posso efectuar mais do que um registo por deposito num mesmo pedido
# 0.7416666666666667 for question id: 178
#
# 82:
# user input: e possivel efectuar mais do que um registo por deposito num mesmo pedido
# 0.7545454545454546 for question id: 202
#
# 82:
# user input: so posso fazer um registo por deposito por cada pedido
# 0.7333333333333334 for question id: 190
#
# 82:
# user input: num so pedido posso efectuar mais do que um registo por deposito
# 0.7454545454545455 for question id: 394
#
# 83:
# user input: quem pode realizar registos por deposito
# 0.7461538461538462 for question id: 106
#
# 83:
# user input: os registos de deposito podem ser realizados por quem
# 0.7642857142857142 for question id: 113
#
# 83:
# user input: quem esta habilitado a realizar registos por deposito
# 0.7391304347826086 for question id: 250
#
# 83:
# user input: quem tem autoridade para realizar registos por deposito
# 0.7375 for question id: 83
#
# 84:
# user input: para que tipo de sociedades posso fazer registos por deposito
# 0.7625 for question id: 84
#
# 84:
# user input: quais os tipos de sociedades para os quais posso fazer registos por deposito
# 0.7461538461538462 for question id: 84
#
# 84:
# user input: os registos por deposito podem ser feitos para que tipos de sociedades
# 0.775 for question id: 113
#
# 84:
# user input: qual a tipologia de sociedades para as quais se podem fazer registos por deposito
# 0.7535714285714286 for question id: 84
#
# 85:
# user input: qual o custo associado ao pedido de registo por deposito
# 0.775 for question id: 170
#
# 85:
# user input: quanto custa o pedido de registo por deposito
# 0.7545454545454546 for question id: 170
#
# 85:
# user input: qual o preco associado ao pedido de registo por deposito
# 0.7576923076923077 for question id: 190
#
# 85:
# user input: o registo por deposito custa quanto
# 0.7461538461538462 for question id: 106
#
# 86:
# user input: e necessario submeter documentos para efectivar o registo por deposito
# 0.7562500000000001 for question id: 106
#
# 86:
# user input: para efectivar o registo por deposito e necessario submeter documentos
# 0.7562500000000001 for question id: 106
#
# 86:
# user input: tenho que submeter documentos para efectivar o registo por deposito
# 0.775 for question id: 86
#
# 86:
# user input: e preciso submeter documentos para efectivar o registo por deposito
# 0.7562500000000001 for question id: 106
#
# 87:
# user input: devo pedir o registo online do projecto de fusao
# 0.76 for question id: 88
#
# 87:
# user input: tenho que pedir o registo online do projecto de fusao
# 0.7685714285714286 for question id: 88
#
# 87:
# user input: preciso de pedir o registo online de projecto de fusao
# 0.7545454545454546 for question id: 170
#
# 87:
# user input: o registo online do projecto de fusao tem de ser pedido
# 0.7685714285714286 for question id: 88
#
# 88:
# user input: devo pedir o registo online do projecto de fusao sobre cada uma das entidades participantes
# 0.7789473684210526 for question id: 88
#
# 88:
# user input: e necessario pedir o registo online do projecto de fusao de cada uma das entidades participantes
# 0.7692307692307692 for question id: 88
#
# 88:
# user input: preciso do registo online de fusao referente a cada uma das entidades participantes
# 0.7545454545454546 for question id: 202
#
# 88:
# user input: tenho que requerer o registo online de fusao de cada entidade participante
# 0.75 for question id: 90
#
# 89:
# user input: posso publicar a convocatoria da assembleia geral para deliberacao da fusao ou cisao no momento do pedido do registo do respectivo projecto
# 0.7642857142857142 for question id: 89
#
# 89:
# user input: a quando do pedido do registo do projeto de fusao ou cisao posso publicar a convocatoria da assembleia geral para deliberacao do respectivo projeto
# 0.7529411764705882 for question id: 190
#
# 89:
# user input: a convocatoria da assembleia geral para deliberacao da fusao ou cisao pode ser publicada quando for feito o pedido de registo do respectivo projeto
# 0.76 for question id: 90
#
# 89:
# user input: e permitido publicar a convocatoria da assembleia geral para deliberacao da fusao ou cisao no momento do pedido do registo do respectivo projecto
# 0.7714285714285714 for question id: 89
#
# 90:
# user input: posso publicar as convocatorias para as assembleias gerais de todas as entidades participantes na fusao
# 0.7384615384615385 for question id: 90
#
# 90:
# user input: as convocatorias para as assembleias gerais de todas as entidades participantes na fusao podem ser publicadas
# 0.7428571428571429 for question id: 425
#
# 90:
# user input: e permitido publicar as convocatorias para as assembleias gerais de todas as entidades participantes na fusao
# 0.7461538461538462 for question id: 90
#
# 90:
# user input: publicar as convocatorias para as assembleias gerais de todas as entidades participantes na fusao e permitido
# 0.7461538461538462 for question id: 90
#
# 91:
# user input: quanto tempo demora a realizacao do registo por deposito
# 0.7666666666666666 for question id: 202
#
# 91:
# user input: qual a duracao da realizacao do registo por deposito
# 0.7882352941176471 for question id: 202
#
# 91:
# user input: a realizacao do registo por deposito demora quanto tempo
# 0.7666666666666666 for question id: 202
#
# 91:
# user input: depois do pagamento quando fica realizado o registo por deposito
# 0.7562500000000001 for question id: 106
#
# 92:
# user input: a que tipos de certidao permanente posso ter acesso
# 0.8263157894736841 for question id: 92
#
# 92:
# user input: a que tipos de certidao permanente posso aceder
# 0.79 for question id: 92
#
# 92:
# user input: posso aceder a que tipos de certidao permanente
# 0.79 for question id: 92
#
# 92:
# user input: que tipos de certidao permanente e que estao acessiveis
# 0.7714285714285714 for question id: 92
#
# 93:
# ...
#
# 585:
# user input: podem existir alteracoes nos feriados
# 0.7250000000000001 for question id: 597
#
# 586:
# user input: alem dos feriados obrigatorias podem ser observados outros
# 0.7428571428571429 for question id: 586
#
# 586:
# user input: existem mais feriados para alem dos obrigatorios
# 0.7153846153846154 for question id: 591
#
# 586:
# user input: para alem dos feriados obrigatorios existem outros
# 0.7206896551724138 for question id: 586
#
# 586:
# user input: existem outros feriados que nao sejam obrigatorios
# 0.7321428571428572 for question id: 586
#
# 587:
# user input: o que e o benchmarking
# 0.7428571428571429 for question id: 599
#
# 587:
# user input: qual e a definicao de benchmarking
# 0.7428571428571429 for question id: 606
#
# 587:
# user input: o que significa benchmarking
# 0.7285714285714286 for question id: 588
#
# 587:
# user input: como se define benchmarking
# 0.7285714285714286 for question id: 588
#
# 588:
# user input: em que situacoes se recorre ao benchmarking
# 0.7545454545454546 for question id: 588
#
# 588:
# user input: quando se recorre ao benchmarking
# 0.7428571428571429 for question id: 588
#
# 588:
# user input: quando comeca um processo de benchmarking
# 0.775 for question id: 588
#
# 588:
# user input: quando se deve usar benchmarking
# 0.7428571428571429 for question id: 588
#
# 589:
# user input: o que e um plano de negocios
# 0.7789473684210526 for question id: 590
#
# 589:
# user input: o que se entende por plano de negocios
# 0.7580645161290323 for question id: 589
#
# 589:
# user input: o que significa plano de negocios
# 0.763157894736842 for question id: 590
#
# 589:
# user input: a que diz respeito um plano de negocios
# 0.775 for question id: 590
#
# 590:
# user input: em que altura se deve redigir o plano de negocios
# 0.7521739130434782 for question id: 590
#
# 590:
# user input: quando se deve redigir o plano de negocios
# 0.7571428571428571 for question id: 590
#
# 590:
# user input: o plano de negocios deve ser redigido em que altura
# 0.7681818181818182 for question id: 590
#
# 590:
# user input: em que fase deve compor um plano de negocios
# 0.7545454545454546 for question id: 590
#
# 591:
# user input: como obter informação económicaestatística sobre um determinado mercado externo
# 0.7146341463414634 for question id: 591
#
# 591:
# user input: onde encontrar informacao sobre mercados externos
# 0.7243243243243243 for question id: 591
#
# 591:
# user input: onde obter informacao relativa a mercados externos
# 0.7236842105263158 for question id: 591
#
# 591:
# user input: como encontrar informacao relativa a um dado mercado externo
# 0.7193548387096774 for question id: 600
#
# 592:
# user input: quais as fontes de informação mais utilizadas na informação económica e estatística sobre comércio internacional e indicadores macroeconómicos
# 0.7558139534883721 for question id: 592
#
# 592:
# user input: quais as fontes de informacao mais relevantes no contexto de informacao economica e estatistica sobre comércio internacional e indicadores macroeconómicos
# 0.7319148936170212 for question id: 592
#
# 592:
# user input: das fontes consultadas quais as que mais se destacam no ambito de informacao economica e estatistica sobre comércio internacional e indicadores macroeconómicos
# 0.736 for question id: 592
#
# 592:
# user input: sobre informacao economicaestatistica quais as fontes mais importantes
# 0.7225 for question id: 592
#
# 593:
# user input: posso suspender a actividade da minha empresa de trabalho temporário por quanto tempo
# 0.763157894736842 for question id: 593
#
# 593:
# user input: a atividade da minha empresa de trabalho temporario pode ser suspensa durante quanto tempo
# 0.7525 for question id: 593
#
# 593:
# user input: e possivel suspender a atividade da minha empresa de trabalho temporario por que periodo de tempo
# 0.7428571428571429 for question id: 593
#
# 593:
# user input: por quanto tempo posso suspender a atividade da minha empresa de trabalho temporario
# 0.745 for question id: 593
#
# 594:
# user input: o que devo fazer para requerer a suspensão da actividade
# 0.7461538461538462 for question id: 594
#
# 594:
# user input: como posso desencadear o processo de suspensao de atividade
# 0.7333333333333334 for question id: 599
#
# 594:
# user input: como devo proceder para suspender a atividade da minha empresa
# 0.7292682926829268 for question id: 594
#
# 594:
# user input: para suspender a atividade como devo prosseguir
# 0.7272727272727273 for question id: 596
#
# 595:
# user input: o acesso a documentos administrativos foime negado por um organismo da administração pública existe alguma entidade a que possa recorrer para saber se tenho direito a consultálos
# 0.7633802816901409 for question id: 595
#
# 595:
# user input: existe algum organismo ao qual possa recorrer apos ter sido negado acesso a documentos admnistrativos
# 0.7333333333333334 for question id: 598
#
# 595:
# user input: um organismo publico negoume acesso a documentos admnistrativos e possivel recorrer desta decisao
# 0.7363636363636363 for question id: 600
#
# 595:
# user input: e possivel recorrer a alguma entidade por me terem negado acesso a documentos admnistrativos
# 0.736 for question id: 598
#
# 596:
# user input: em que consiste a atividade de comércio a retalho não sedentário
# 0.8263157894736841 for question id: 596
#
# 596:
# user input: o que e a atividade de comércio a retalho não sedentário
# 0.8049999999999999 for question id: 596
#
# 596:
# user input: o que e comércio a retalho não sedentário
# 0.775 for question id: 596
#
# 596:
# user input: a que se refere a atividade de comércio a retalho não sedentário
# 0.8049999999999999 for question id: 596
#
# 597:
# user input: que entidades podem organizar feiras retalhistas
# 0.8666666666666667 for question id: 597
#
# 597:
# user input: que entidades tem direito a organizar feiras de retalho
# 0.7642857142857142 for question id: 597
#
# 597:
# user input: por quem podem ser organizadas feiras retalhistas
# 0.775 for question id: 597
#
# 597:
# user input: quem pode organizar feiras retalhistas
# 0.79 for question id: 597
#
# 598:
# user input: onde poderei ter acesso ao plano anual de feiras e dos locais onde se realizam os eventos
# 0.75 for question id: 599
#
# 598:
# user input: onde posso ver o plano anual de feiras e localizacao
# 0.7666666666666666 for question id: 599
#
# 598:
# user input: qual o site com informacao do plano anual de feiras e locais dos eventos
# 0.7714285714285714 for question id: 599
#
# 598:
# user input: onde posso aceder ao plano anual de feiras e locais
# 0.7473684210526316 for question id: 599
#
# 599:
# user input: qual o código da classificação das atividades económicas cae para “organização de feiras congressos e outros eventos similares”
# 0.8285714285714285 for question id: 599
#
# 599:
# user input: qual a codificacao da classificação das atividades económicas cae para “organização de feiras congressos e outros eventos similares”
# 0.791304347826087 for question id: 599
#
# 599:
# user input: qual o código da cae para “organização de feiras congressos e outros eventos similares”
# 0.8588235294117648 for question id: 599
#
# 599:
# user input: relativamente a “organização de feiras congressos e outros eventos similares” qual e o codigo da cae
# 0.8263157894736841 for question id: 599
#
# 600:
# user input: quando se considera que existe prestacao de servicos de alojamento turistico
# 0.7517241379310344 for question id: 600
#
# 600:
# user input: quando existe prestacao de servicoes de alojamento turistico
# 0.7444444444444445 for question id: 600
#
# 600:
# user input: quais as condicoes necessarias para que ocorra prestacao de servicos de alojamento turistico
# 0.7375 for question id: 600
#
# 600:
# user input: quando ha prestacao de servicos de alojamento turistico
# 0.7576923076923077 for question id: 600
#
# 601:
# user input: a ficha de seguranca contra riscos de incendio deve ser entregue aquando da comunicacao de abertura de um empreendimento turistico
# 0.7319148936170212 for question id: 601
#
# 601:
# user input: devese entregar a ficha de seguranca contra riscos de incendio no acto de comunicacao de abertura de um empreendimento turistico
# 0.7287234042553192 for question id: 601
#
# 601:
# user input: quando e feita a comunicacao de abertura de um empreendimento turistico deve ser entregue a ficha de seguranca contra riscos de incendio
# 0.7315789473684211 for question id: 601
#
# 601:
# user input: apara comunicacao de abertura de um empreendimento turistico e necessario entregar a ficha de seguranca contra riscos de incendio
# 0.7290322580645161 for question id: 606
#
# 602:
# user input: a realizacao de leiloes em espaco publico tambem passou a ser dispensada de licenca de ocupacao de espaco publico
# 0.7638297872340425 for question id: 602
#
# 602:
# user input: ja nao e necessario licenca de ocupacao de espaco publico para a realizacao de leiloes em espaco publico
# 0.7782608695652173 for question id: 602
#
# 602:
# user input: deixou de ser preciso licenca de ocupacao de espaco publico para a realizacao de leiloes em espaco publico
# 0.7717391304347827 for question id: 602
#
# 602:
# user input: e possivel realizar leiloes em espaco publico sem a licenca de ocupacao de espaco publico
# 0.7574468085106383 for question id: 602
#
# 603:
# user input: o que e a ordem dos engenheiros
# 0.7525 for question id: 603
#
# 603:
# user input: o que significa ordem dos engenheiros
# 0.7365853658536585 for question id: 603
#
# 603:
# user input: qual e a associacao publica representativa dos engenheiros
# 0.7363636363636363 for question id: 604
#
# 603:
# user input: qual a ordem dos profissionais de engenharia
# 0.7357142857142858 for question id: 603
#
# 604:
# user input: o que e a ordem dos medicos veterinarios
# 0.746875 for question id: 604
#
# 604:
# user input: o que significa ordem dos medicos veterinarios
# 0.7272727272727273 for question id: 604
#
# 604:
# user input: qual e a associacao publica representativa dos medicos veterinarios
# 0.7352941176470589 for question id: 604
#
# 604:
# user input: qual a ordem dos profissionais de medicina veterinaria
# 0.7363636363636363 for question id: 604
#
# 605:
# user input: o que e um fornecedor de plantas horticolas ou de materiais fruticolas
# 0.7562500000000001 for question id: 605
#
# 605:
# user input: o que se entende por fornecedor de plantas horticolas ou de materiais fruticolas
# 0.7441176470588236 for question id: 605
#
# 605:
# user input: qual a definicao de fornecedor de plantas hortiolas ou de materiais fruticolas
# 0.75 for question id: 606
#
# 605:
# user input: o que caracteriza um fornecedor de plantas horticolas ou de materiais fruticolas
# 0.7454545454545455 for question id: 605
#
# 606:
# user input: o que e uma plantamae
# 0.7310344827586207 for question id: 607
#
# 606:
# user input: o que signifca plantamae
# 0.71 for question id: 607
#
# 606:
# user input: qual e a definicao de plantamae
# 0.7428571428571429 for question id: 606
#
# 606:
# user input: qual o significado de plantamae
# 0.72 for question id: 607
#
# 607:
# user input: o que se entende por clone
# 0.7193548387096774 for question id: 607
#
# 607:
# user input: o que e um clone na pratica horticola
# 0.728125 for question id: 607
#
# 607:
# user input: a que se refere o termo clone
# 0.7290322580645161 for question id: 607
#
# 607:
# user input: o que significa clone
# 0.7206896551724138 for question id: 607
#
# 608:
# user input: estou desempregrado pretendo criar o meu proprio emprego o iefp tem apoios para a minha situacao
# 0.7289156626506024 for question id: 608
#
# 608:
# user input: nao tenho emprego e quero criar a minha propria empresa ha apoios do governo
# 0.7253012048192771 for question id: 608
#
# 608:
# user input: ha apoios do iefp para quem se encontra desempregado e quer criar o seu proprio emprego
# 0.7407407407407407 for question id: 608
#
# 608:
# user input: nao tenho emprego e quer criar o meu proprio negocio ha alguma ajuda governamental
# 0.7176470588235294 for question id: 608
#
# 609:
# user input: sou jovem e nunca estive empregado gostaria de criar a minha propria empresa o iefp pode ajudarme
# 0.7428571428571429 for question id: 491
#
# 609:
# user input: nunca tive emprego sou jovem e quero criar a minha empresa ha apoios do iefp
# 0.7148148148148148 for question id: 613
#
# 609:
# user input: ha ajudas do iefp para jovens que nunca tenham estado empregados que desejem comecar a sua propria empresa
# 0.7222222222222222 for question id: 613
#
# 609:
# user input: o iefp possui apoios para jovens que nunca tenham trabalhado interessados em criar o seu proprio negocio
# 0.7185185185185186 for question id: 613
#
# 610:
# user input: sou beneficiario do subsidio de desemprego mas gostaria de abrir o meu proprio negocio o iefp tem algum apoio especifico para a minha situacao
# 0.741860465116279 for question id: 464
#
# 610:
# user input: ha programas especificos do iefp para quem receba subsidio de desemprego e queira abrir a sua propria empresa
# 0.7259259259259259 for question id: 613
#
# 610:
# user input: recebo o subsidio de desemprego mas desejo criar uma empresa o iefp possui apoios para este caso
# 0.7211764705882353 for question id: 612
#
# 610:
# user input: o iefp tem algum apoio especifico para quem deseja criar o seu proprio negocio mas receba o subsidio de desemprego
# 0.7180722891566265 for question id: 613
#
# 611:
# user input: pretendo constituir uma empresa de trabalho temporario ett como devo proceder
# 0.7225 for question id: 612
#
# 611:
# user input: como devo proceder para abrir uma empresa de trabalho temporario ett
# 0.7225 for question id: 612
#
# 611:
# user input: qual e o procedimento para constituir uma empresa de trabalho temporario ett
# 0.728 for question id: 613
#
# 611:
# user input: quero abrir uma empresa de trabalho temporario ett como e suposto proceder
# 0.7262500000000001 for question id: 612
#
# 612:
# user input: que requisitos devo preencher em termos de capacidades tecnicas para exercer funcoes como director tecnico de uma empresa de trabalho temporario
# 0.7357142857142858 for question id: 612
#
# 612:
# user input: que capacidades tecnicas devo ter para numa empresa de trabalho temporario exercer funcoes de director tecnico
# 0.7253012048192771 for question id: 612
#
# 612:
# user input: para exercer o cargo de director tecnico numa empresa de trabalho temporario que capacidades tecnicas sao necessarias
# 0.7329268292682927 for question id: 612
#
# 612:
# user input: no que toca a capacidades tecnicas quais sao os requisitos para poder exercer funcoes como director tecnico de uma empresa de trabalho temporario
# 0.7423529411764707 for question id: 612
#
# 613:
# user input: para poder funcionar a minha empresa de trabalho temporario tem de constituir uma caucao a favor do iefp para que serve essa caucao e qual o seu valor
# 0.7569620253164557 for question id: 613
#
# 613:
# user input: qual o valor e a funcao da caucao que as empresas de trabalho temporario tem de pagar ao iefp
# 0.752 for question id: 613
#
# 613:
# user input: a minha empresa de trabalho temporario tem de constituir uma caucao a favor do iefp para poder funcionar qual o valor e funcao desta caucao
# 0.7493670886075949 for question id: 613
#
# 613:
# user input: uma empresa de trabalho temporario necessita de constituir uma caucao a favor do iefp para poder funcionar esta caucao serve que proposito e qual o seu valor
# 0.7569620253164557 for question id: 613
#
# 614:
# user input: qual e a definicao nacional de pequena e media empresa pme
# 0.7198347107438017 for question id: 615
#
# 614:
# user input: qual e a definicao portuguesa de uma pequena e media empresa pme
# 0.7223140495867768 for question id: 615
#
# 614:
# user input: como se define uma pequena e media empresa pme em portugal
# 0.7196721311475409 for question id: 615
#
# 614:
# user input: como se define nacionalmente uma pequena e media empresa pme
# 0.7172131147540983 for question id: 615
#
# 615:
# user input: qual a definicao europeia de micro pequena e media empresa pme
# 0.7250000000000001 for question id: 615
#
# 615:
# user input: a nivel europeu como se define micro pequena e media empresa pme
# 0.7221311475409836 for question id: 615
#
# 615:
# user input: qual a definicao de micro pequena e media empresa pme a nivel europeu
# 0.7247933884297522 for question id: 615
#
# 615:
# user input: na europa qual a definicao de micro pequena e media empresa pme
# 0.7221311475409836 for question id: 615
#
# Seconds to process:66.92591094970703

# %%
a = '    '
not a.isspace()
# Out:
# False
