# %%
import xml.etree.ElementTree as ET
root = ET.parse('KB.xml').getroot()

# %%
for type_tag in root.findall('documento/faq_list/faq/perguntas/pergunta'):
    value = type_tag.get('pergunta')
    print(type_tag)
# Out:
# <Element 'pergunta' at 0x1057c8598>
# <Element 'pergunta' at 0x1057c8458>
# <Element 'pergunta' at 0x105fe24f8>
# <Element 'pergunta' at 0x105fe2548>
# <Element 'pergunta' at 0x105fe26d8>
# <Element 'pergunta' at 0x105fe2728>
# <Element 'pergunta' at 0x105fe2778>
# <Element 'pergunta' at 0x105fe27c8>
# <Element 'pergunta' at 0x105fe2958>
# <Element 'pergunta' at 0x105fe29a8>
# <Element 'pergunta' at 0x105fe29f8>
# <Element 'pergunta' at 0x105fe2a48>
# <Element 'pergunta' at 0x105fe2c28>
# <Element 'pergunta' at 0x105fe2c78>
# <Element 'pergunta' at 0x105fe2cc8>
# <Element 'pergunta' at 0x105fe2d18>
# <Element 'pergunta' at 0x105fe2ea8>
# <Element 'pergunta' at 0x105fe2ef8>
# <Element 'pergunta' at 0x105fe2f48>
# <Element 'pergunta' at 0x105fe2f98>
# <Element 'pergunta' at 0x105ae3188>
# <Element 'pergunta' at 0x105ae31d8>
# <Element 'pergunta' at 0x105ae3228>
# <Element 'pergunta' at 0x105ae3278>
# <Element 'pergunta' at 0x105ae3408>
# <Element 'pergunta' at 0x105ae3458>
# ...

# %%
from xml.dom import minidom
xmldoc = minidom.parse('KB.xml')

itemlist = xmldoc.getElementsByTagName('pergunta')
print(itemlist[0])
# Out:
# <DOM Element: pergunta at 0x105f6d800>

# %%
import xml.etree.cElementTree as ET

tree = ET.parse("KB.xml")
root = tree.getroot() 
root_tag = root.tag
print(root_tag) 

for form in root.findall("documento/faq_list/faq/perguntas/pergunta"):
    print(form)
# Out:
# documentos
# <Element 'pergunta' at 0x105acee08>
# <Element 'pergunta' at 0x105acec78>
# <Element 'pergunta' at 0x105acedb8>
# <Element 'pergunta' at 0x105aced68>
# <Element 'pergunta' at 0x105aceb88>
# <Element 'pergunta' at 0x105ace9f8>
# <Element 'pergunta' at 0x105aceb38>
# <Element 'pergunta' at 0x105aceae8>
# <Element 'pergunta' at 0x105ace8b8>
# <Element 'pergunta' at 0x105ace908>
# <Element 'pergunta' at 0x105ace728>
# <Element 'pergunta' at 0x105ace868>
# <Element 'pergunta' at 0x105ace638>
# <Element 'pergunta' at 0x105ace4a8>
# <Element 'pergunta' at 0x105ace5e8>
# <Element 'pergunta' at 0x105ace598>
# <Element 'pergunta' at 0x105ace3b8>
# <Element 'pergunta' at 0x105ace228>
# <Element 'pergunta' at 0x105ace368>
# <Element 'pergunta' at 0x105ace318>
# <Element 'pergunta' at 0x105ace138>
# <Element 'pergunta' at 0x105ace048>
# <Element 'pergunta' at 0x106227138>
# <Element 'pergunta' at 0x106227188>
# <Element 'pergunta' at 0x106227f98>
# ...

# %%
from xml.dom import minidom

# parse an xml file by name
mydoc = minidom.parse('KB.xml')

perguntas = mydoc.getElementsByTagName('perguntas')
numbQuestions= len(perguntas)
#QuestionMatrix=
# all items data
print('\nAll item data:')
i=0
for elem in perguntas:
    #print('\n'+elem.firstChild.data+'\n'+str(i))
    i+=1
print(numbQuestions)
i=0
pergunta = mydoc.getElementsByTagName('pergunta')  
for elem in pergunta:
    #print('\n'+elem.firstChild.data+'\n'+str(i))
    i+=1
print(i)
# Out:
# All item data:
# 615
# 2641

# %%
from xml.dom import minidom

mydoc = minidom.parse('KB.xml')

perguntas = mydoc.getElementsByTagName('perguntas')
numbQuestions = len(perguntas)

pergunta = mydoc.getElementsByTagName('pergunta')
numbIterations = len(pergunta)

print('Number of questions: '+str(numbQuestions)+
      '\n Number of question iterations: '+str(numbIterations)+
      '\n Number of iterations per question: '+str(numbIterations/numbQuestions))
# Out:
# Number of questions: 615
#  Number of question iterations: 2641
#  Number of iterations per question: 4.294308943089431

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('KB.xml')
root = tree.getroot()

QuestionNumber = 0

NumberOfQuestions = 0

Answers = {}
Questions = {}


# all items data
print('\nAll item data:')
for documento in root:
    print('Documento:')
    print(documento.text)
    for faq_list in documento:
        #print(faq_list.text)
        #print('faq_list:')
        for faq in faq_list:
            #print('faq text:')
            #print(faq.text)
            for perguntas in faq:
                #print('perguntas')
                if len(perguntas.attrib)!= 0:
                    print('\n ID to return: '+perguntas.attrib['id'])
                    answer_id = perguntas.attrib['id']
                    answer = perguntas.text
                    print('\n Answer: '+ answer )
                    #print(perguntas.text)
                
                QuestionNumber = 0
                for pergunta in perguntas:
                    
                    print('\n '+str(QuestionNumber)+': '+pergunta.text)
                    QuestionNumber += 1
                    NumberOfQuestions += 1
# Out:
# All item data:
# Documento:
#
#
#
#  0: Pode ser emitido Cartão Eletrónico da Empresa ou de Pessoa Coletiva às entidades titulares de Cartão Definitivo de Identificação de Pessoa Coletiva ou entidade equiparada, emitido antes do dia 31/12/2008 ou inscritas anteriormente a essa data?
#
#  1: É possível emitir Cartão Eletrónico da Empresa ou de Pessoa Coletiva às entidades titulares de Cartão Definitivo de Identificação de Pessoa Coletiva ou entidade equiparada, emitido antes do dia 31/12/2008 ou inscritas anteriormente a essa data?
#
#  2: Posso mandar fazer o Cartão Eletrónico da Empresa ou de Pessoa Coletiva às entidades titulares de Cartão Definitivo de Identificação de Pessoa Coletiva ou entidade equiparada, emitido antes do dia 31/12/2008 ou inscritas antes dessa data?
#
# ...

# %%
streetno = {"1": "Sachine Tendulkar",
            "2": "Dravid",
            "3": "Sehwag",
            "4": "Laxman",
            "5": "Kohli" }
streetno["1"]
# Out:
# 'Sachine Tendulkar'
